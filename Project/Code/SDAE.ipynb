# %%
import os
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.feature_selection import RFE
from imblearn.over_sampling import SMOTE
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## **1st Variation: miRNA**

# %%
# Load the dataset
file_path = 'miRNA_data_250.csv'  # Make sure the file is in the same directory or provide the correct path
miRNA = pd.read_csv(file_path)
label = pd.read_csv("BRCA_label.csv")

# %%
# Print the number of rows and columns
print(f"Number of rows (labels): {label.shape[0]}")
print(f"Number of columns (labels): {label.shape[1]}")

# Print the number of features
print(f"Number of features (labels): {label.shape[1]}")
print('\n')

# Print the number of rows and columns
print(f"Number of rows (miRNA): {miRNA.shape[0]}")
print(f"Number of columns (miRNA): {miRNA.shape[1]}")

# Print the number of features
print(f"Number of features (miRNA): {miRNA.shape[1]}")

# %%
label.head(10)

# %%
# Replace label with numerical data
label['Label'].replace('Normal', 0, inplace=True)
label['Label'].replace('LumA', 1, inplace=True)
label['Label'].replace('LumB', 2, inplace=True)
label['Label'].replace('Basal', 3, inplace=True)
label['Label'].replace('Her2', 4, inplace=True)

# Print the updated dataset
print(label)

# %%
# CHECK FOR MISSING VALUES  
print("Missing values in label dataset:")
print(label.isnull().sum())
print("\n")

print("Missing values in miRNA dataset:")
print(miRNA.isnull().sum())

# %%
# ADD LABEL
miRNA['Label'] = label['Label'].values
miRNA.head(5)

# %% [markdown]
# ### **Without SMOTE**

# %%
train_data, test_data = train_test_split(miRNA,test_size=0.20,random_state=1)
target="Label"
X_train = train_data.select_dtypes(include=["number"]).copy()
y_train = train_data[target]
X_test = test_data.select_dtypes(include=["number"]).copy()
y_test = test_data[target]

# %%
# Standardize the data
scaler = StandardScaler()
x_train_miRNA = scaler.fit_transform(X_train)
x_test_miRNA = scaler.transform(X_test)

# Define the architecture parameters
input_dim = x_train_miRNA.shape[1]
hidden1_dim = 64
hidden2_dim = 32
encoding_dim = 16

# Build the SDAE model
input_layer = Input(shape=(input_dim,))
hidden1 = Dense(hidden1_dim, activation='relu')(input_layer)
encoded1 = Dense(hidden2_dim, activation='relu')(hidden1)
encoded2 = Dense(encoding_dim, activation='relu')(encoded1)
decoded1 = Dense(hidden2_dim, activation='relu')(encoded2)
decoded2 = Dense(hidden1_dim, activation='relu')(decoded1)
output_layer = Dense(input_dim, activation='linear')(decoded2)

sdae = Model(inputs=input_layer, outputs=output_layer)

# Compile the SDAE model
sdae.compile(optimizer='adam', loss='mean_squared_error')

# Train the SDAE
num_epochs = 250
batch_size = 32
sdae.fit(x_train_miRNA, x_train_miRNA, epochs=num_epochs, batch_size=batch_size, shuffle=True, validation_data=(x_test_miRNA, x_test_miRNA))

# Extract the encoder part for feature extraction
encoder = Model(inputs=input_layer, outputs=encoded2)

# Extract features using the encoder
X_train_encoded = encoder.predict(x_train_miRNA)
X_test_encoded = encoder.predict(x_test_miRNA)

# Define a classifier (example: simple MLP classifier)
num_classes = len(np.unique(y_train))
classifier = Sequential([
    Dense(64, activation='relu', input_dim=encoding_dim),
    Dropout(0.5),
    Dense(32, activation='relu'),
    Dropout(0.5),
    Dense(num_classes, activation='softmax')
])

# Compile and train the classifier
classifier.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
num_epochs = 250
batch_size = 32
classifier.fit(X_train_encoded, y_train, epochs=num_epochs, batch_size=batch_size, validation_data=(X_test_encoded, y_test))

# Predict probabilities
y_pred_prob = classifier.predict(X_test_encoded)

# Convert probabilities to class labels
y_pred = np.argmax(y_pred_prob, axis=1)

# %%
from sklearn.metrics import accuracy_score

# Accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")

# %% [markdown]
# ### **With SMOTE**

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from imblearn.over_sampling import SMOTE
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score, precision_score, recall_score, f1_score
from collections import Counter
from tensorflow.keras.layers import Input, Dense, Dropout
from keras.models import Model, Sequential
from tensorflow.keras.callbacks import EarlyStopping
from keras.optimizers import Adam

# Load the dataset
omics_data = pd.read_csv(r'D:\uni dina\4Y SEM 8\Bioinformatics Modeling and Simulation\_GROUP PROJECT\VERSION 3\DATASET\miRNA_data_250.csv')
labels = pd.read_csv(r'D:\uni dina\4Y SEM 8\Bioinformatics Modeling and Simulation\_GROUP PROJECT\VERSION 3\DATASET\BRCA_label.csv')

# %%
omics_data

# %%
# Preprocess the labels
label_encoder = LabelEncoder()
labels['label_encoded'] = label_encoder.fit_transform(labels['Label'])

# Print label mappings
label_mappings = dict(zip(label_encoder.classes_, label_encoder.transform(label_encoder.classes_)))
print("Label Mappings:")
for label, encoded_value in label_mappings.items():
    print(f"{label} - {encoded_value}")

# %%
# Print class distribution
class_distribution = Counter(labels['label_encoded'])
print("\nClass Distribution:")
for label, count in class_distribution.items():
    for key, value in label_mappings.items():
        if value == label:
            print(f"{key} - {label} - {count}")

# %%
omics_data = omics_data.iloc[:, 1:]
omics_data

# %%
# Split the data
X_train, X_test, y_train, y_test = train_test_split(omics_data, labels['label_encoded'], test_size=0.2, random_state=42)

# Print class distribution before SMOTE
print("Class distribution before SMOTE:")
print(pd.Series(y_train).value_counts())

# %%
# Split data into training and test sets
x_train, x_test, y_train, y_test = train_test_split(omics_data, labels['label_encoded'], test_size=0.2, random_state=42)

# Apply SMOTE to balance the training data
smote = SMOTE(random_state=42)
x_train_smote, y_train_smote = smote.fit_resample(x_train, y_train)

# Print class distribution after SMOTE
print("\nClass distribution after SMOTE:")
print(pd.Series(y_train_smote).value_counts())

# %%
# Standardize the data
scaler = StandardScaler()
x_train_smote = scaler.fit_transform(x_train_smote)
x_test = scaler.transform(x_test)

# Define the architecture parameters for the SDAE
input_dim = x_train_smote.shape[1]
hidden1_dim = 64
hidden2_dim = 32
encoding_dim = 16

# Build the SDAE model
input_layer = Input(shape=(input_dim,))
hidden1 = Dense(hidden1_dim, activation='relu')(input_layer)
encoded1 = Dense(hidden2_dim, activation='relu')(hidden1)
encoded2 = Dense(encoding_dim, activation='relu')(encoded1)
decoded1 = Dense(hidden2_dim, activation='relu')(encoded2)
decoded2 = Dense(hidden1_dim, activation='relu')(decoded1)
output_layer = Dense(input_dim, activation='linear')(decoded2)

sdae = Model(inputs=input_layer, outputs=output_layer)

# Compile the SDAE model
sdae.compile(optimizer='adam', loss='mean_squared_error')

# Train the SDAE
num_epochs = 250
batch_size = 32
sdae.fit(x_train_smote, x_train_smote, epochs=num_epochs, batch_size=batch_size, shuffle=True, validation_data=(x_test, x_test))

# Extract the encoder part for feature extraction
encoder = Model(inputs=input_layer, outputs=encoded2)

# Extract features using the encoder
X_train_encoded = encoder.predict(x_train_smote)
X_test_encoded = encoder.predict(x_test)

# Define a classifier (example: simple MLP classifier)
num_classes = len(np.unique(y_train))
classifier = Sequential([
    Dense(64, activation='relu', input_dim=encoding_dim),
    Dropout(0.5),
    Dense(32, activation='relu'),
    Dropout(0.5),
    Dense(num_classes, activation='softmax')
])

# Compile and train the classifier
classifier.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
num_epochs = 250
batch_size = 32
classifier.fit(X_train_encoded, y_train_smote, epochs=num_epochs, batch_size=batch_size, validation_data=(X_test_encoded, y_test))

# Predict probabilities
y_pred_prob = classifier.predict(X_test_encoded)

# Convert probabilities to class labels
y_pred = np.argmax(y_pred_prob, axis=1)

# Evaluate the classifier
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy}')
print(classification_report(y_test, y_pred))

# %%
# Evaluate model
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')

print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")

# Detailed classification report
print(classification_report(y_test, y_pred, target_names=label_encoder.classes_))

# %% [markdown]
# ## **2nd Variation: CNV**

# %%
# Load the dataset
file_path = 'cnv_data_5000.csv'  # Make sure the file is in the same directory or provide the correct path
cnv = pd.read_csv(file_path)
label = pd.read_csv("BRCA_label.csv")

# %%
# Print the number of rows and columns
print(f"Number of rows (labels): {label.shape[0]}")
print(f"Number of columns (labels): {label.shape[1]}")

# Print the number of features
print(f"Number of features (labels): {label.shape[1]}")
print('\n')

# Print the number of rows and columns
print(f"Number of rows (cnv): {cnv.shape[0]}")
print(f"Number of columns (cnv): {cnv.shape[1]}")

# Print the number of features
print(f"Number of features (cnv): {cnv.shape[1]}")
# Out:
# Number of rows (labels): 671
# Number of columns (labels): 1
# Number of features (labels): 1
#
#
# Number of rows (cnv): 671
# Number of columns (cnv): 5001
# Number of features (cnv): 5001

# %%
label.head(10)
# Out:
#     Label
# 0    LumA
# 1    Her2
# 2    LumB
# 3    LumA
# 4    LumA
# 5    LumB
# 6  Normal
# 7    LumA
# 8    LumA
# 9    LumA

# %%
# Replace label with numerical data
label['Label'].replace('Normal', 0, inplace=True)
label['Label'].replace('LumA', 1, inplace=True)
label['Label'].replace('LumB', 2, inplace=True)
label['Label'].replace('Basal', 3, inplace=True)
label['Label'].replace('Her2', 4, inplace=True)

# Print the updated dataset
print(label)
# Out:
#      Label
# 0        1
# 1        4
# 2        2
# 3        1
# 4        1
# ..     ...
# 666      1
# 667      1
# 668      1
# 669      1
# 670      2
#
# [671 rows x 1 columns]

# %%
# Check for missing values 
print("Missing values in label dataset:")
print(label.isnull().sum())
print("\n")

print("Missing values in miRNA dataset:")
print(cnv.isnull().sum())
# Out:
# Missing values in label dataset:
# Label    0
# dtype: int64
#
#
# Missing values in miRNA dataset:
# Sample    0
# 19        0
# 20        0
# 26        0
# 29        0
#          ..
# 19538     0
# 19548     0
# 19555     0
# 19558     0
# 19559     0
# Length: 5001, dtype: int64

# %%
# Add Label
cnv['Label'] = label['Label'].values
cnv.head(5)
# Out:
#             Sample        19        20        26        29        30  \
# 0  TCGA.3C.AAAU.01  0.168260  1.381866 -0.125490  0.234944  0.186243
# 1  TCGA.3C.AALI.01  0.638828  1.187621  0.694135  0.711597  0.667629
# 2  TCGA.3C.AALJ.01  0.726989  0.967953 -0.142432  0.796425  0.753299
# 3  TCGA.3C.AALK.01  2.778713 -0.528808  0.066625  2.770604  2.747083
# 4  TCGA.5L.AAT0.01 -0.400391 -0.497030  0.545728 -0.288346 -0.342244
#
#          33        35        39        40  ...     19522     19524     19530  \
# 0  0.251305  0.985624  0.255663  0.247536  ...  1.752653  1.611711  0.467152
# 1 -1.761672  1.178340 -1.723665 -1.748310  ... -1.358628 -1.440536  0.996331
# 2  2.505219 -0.647014  2.471900  2.482269  ... -0.760134  0.390717 -0.020916
# 3  2.724154 -0.310827  2.687175  2.699341  ...  0.142044  0.127217 -0.280486
# 4 -0.390351 -0.296148 -0.375268 -0.388660  ...  0.229797  0.067611 -0.106483
#
#       19531     19538     19548     19555     19558     19559  Label
# 0  1.023534  1.432648 -1.048549 -3.241453 -0.837399  2.020624      1
# 1  0.242559  0.473931  0.448365 -0.894137 -1.537275  4.002085      4
# 2 -0.835228 -0.550638 -1.607949  1.314833  4.165544 -0.319977      2
# 3  0.113623  0.519930 -0.019744  0.225309  0.080744 -0.316675      1
# 4  0.144775  0.516541 -0.013269  0.199259  0.045801 -0.307593      1
#
# [5 rows x 5002 columns]

# %% [markdown]
# ### **Without SMOTE**

# %%
train_data, test_data = train_test_split(cnv,test_size=0.20,random_state=1)
target="Label"
X_train = train_data.select_dtypes(include=["number"]).copy()
y_train = train_data[target]
X_test = test_data.select_dtypes(include=["number"]).copy()
y_test = test_data[target]

# %%
# Standardize the data
scaler = StandardScaler()
x_train_cnv = scaler.fit_transform(X_train)
x_test_cnv = scaler.transform(X_test)

# Define the architecture parameters
input_dim = x_train_cnv.shape[1]
hidden1_dim = 64
hidden2_dim = 32
encoding_dim = 16

# Build the SDAE model
input_layer = Input(shape=(input_dim,))
hidden1 = Dense(hidden1_dim, activation='relu')(input_layer)
encoded1 = Dense(hidden2_dim, activation='relu')(hidden1)
encoded2 = Dense(encoding_dim, activation='relu')(encoded1)
decoded1 = Dense(hidden2_dim, activation='relu')(encoded2)
decoded2 = Dense(hidden1_dim, activation='relu')(decoded1)
output_layer = Dense(input_dim, activation='linear')(decoded2)

sdae = Model(inputs=input_layer, outputs=output_layer)

# Compile the SDAE model
sdae.compile(optimizer='adam', loss='mean_squared_error')

# Train the SDAE
num_epochs = 250
batch_size = 32
sdae.fit(x_train_cnv, x_train_cnv, epochs=num_epochs, batch_size=batch_size, shuffle=True, validation_data=(x_test_miRNA, x_test_miRNA))

# Extract the encoder part for feature extraction
encoder = Model(inputs=input_layer, outputs=encoded2)

# Extract features using the encoder
X_train_encoded = encoder.predict(x_train_cnv)
X_test_encoded = encoder.predict(x_test_cnv)

# Define a classifier (example: simple MLP classifier)
num_classes = len(np.unique(y_train))
classifier = Sequential([
    Dense(64, activation='relu', input_dim=encoding_dim),
    Dropout(0.5),
    Dense(32, activation='relu'),
    Dropout(0.5),
    Dense(num_classes, activation='softmax')
])

# Compile and train the classifier
classifier.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
num_epochs = 250
batch_size = 32
classifier.fit(X_train_encoded, y_train, epochs=num_epochs, batch_size=batch_size, validation_data=(X_test_encoded, y_test))

# Predict probabilities
y_pred_prob = classifier.predict(X_test_encoded)

# Convert probabilities to class labels
y_pred = np.argmax(y_pred_prob, axis=1)
# Out:
# Epoch 1/250
# 17/17 [==============================] - 2s 31ms/step - loss: 0.9996 - val_loss: 1.0288
# Epoch 2/250
# 17/17 [==============================] - 0s 25ms/step - loss: 0.9591 - val_loss: 0.9642
# Epoch 3/250
# 17/17 [==============================] - 0s 17ms/step - loss: 0.8952 - val_loss: 0.9255
# Epoch 4/250
# 17/17 [==============================] - 0s 18ms/step - loss: 0.8581 - val_loss: 0.9042
# Epoch 5/250
# 17/17 [==============================] - 0s 17ms/step - loss: 0.8241 - val_loss: 0.8925
# Epoch 6/250
# 17/17 [==============================] - 0s 16ms/step - loss: 0.7964 - val_loss: 0.8784
# Epoch 7/250
# 17/17 [==============================] - 0s 20ms/step - loss: 0.7751 - val_loss: 0.8722
# Epoch 8/250
# 17/17 [==============================] - 0s 17ms/step - loss: 0.7577 - val_loss: 0.8633
# Epoch 9/250
# 17/17 [==============================] - 0s 18ms/step - loss: 0.7446 - val_loss: 0.8616
# Epoch 10/250
# 17/17 [==============================] - 0s 18ms/step - loss: 0.7297 - val_loss: 0.8589
# Epoch 11/250
# 17/17 [==============================] - 0s 16ms/step - loss: 0.7146 - val_loss: 0.8560
# Epoch 12/250
# 17/17 [==============================] - 0s 16ms/step - loss: 0.7014 - val_loss: 0.8544
# Epoch 13/250
# 17/17 [==============================] - 0s 23ms/step - loss: 0.6902 - val_loss: 0.8529
# Epoch 14/250
# 17/17 [==============================] - 0s 28ms/step - loss: 0.6806 - val_loss: 0.8569
# Epoch 15/250
# 17/17 [==============================] - 0s 15ms/step - loss: 0.6735 - val_loss: 0.8522
# Epoch 16/250
# 17/17 [==============================] - 0s 15ms/step - loss: 0.6628 - val_loss: 0.8513
# Epoch 17/250
# 17/17 [==============================] - 0s 14ms/step - loss: 0.6528 - val_loss: 0.8544
# Epoch 18/250
# 17/17 [==============================] - 0s 15ms/step - loss: 0.6465 - val_loss: 0.8568
# Epoch 19/250
# 17/17 [==============================] - 0s 15ms/step - loss: 0.6395 - val_loss: 0.8514
# Epoch 20/250
# 17/17 [==============================] - 0s 15ms/step - loss: 0.6308 - val_loss: 0.8530
# Epoch 21/250
# 17/17 [==============================] - 0s 16ms/step - loss: 0.6222 - val_loss: 0.8573
# Epoch 22/250
# 17/17 [==============================] - 0s 15ms/step - loss: 0.6152 - val_loss: 0.8535
# Epoch 23/250
# 17/17 [==============================] - 0s 17ms/step - loss: 0.6062 - val_loss: 0.8582
# Epoch 24/250
# 17/17 [==============================] - 0s 15ms/step - loss: 0.5982 - val_loss: 0.8647
# Epoch 25/250
# 17/17 [==============================] - 0s 16ms/step - loss: 0.5939 - val_loss: 0.8639
# Epoch 26/250
# 17/17 [==============================] - 0s 16ms/step - loss: 0.5876 - val_loss: 0.8611
# Epoch 27/250
# 17/17 [==============================] - 0s 15ms/step - loss: 0.5812 - val_loss: 0.8666
# Epoch 28/250
# 17/17 [==============================] - 0s 15ms/step - loss: 0.5765 - val_loss: 0.8649
# Epoch 29/250
# 17/17 [==============================] - 0s 14ms/step - loss: 0.5713 - val_loss: 0.8680
# Epoch 30/250
# 17/17 [==============================] - 0s 23ms/step - loss: 0.5672 - val_loss: 0.8682
# Epoch 31/250
# 17/17 [==============================] - 0s 17ms/step - loss: 0.5625 - val_loss: 0.8692
# Epoch 32/250
# 17/17 [==============================] - 0s 18ms/step - loss: 0.5602 - val_loss: 0.8683
# Epoch 33/250
# 17/17 [==============================] - 0s 19ms/step - loss: 0.5554 - val_loss: 0.8696
# Epoch 34/250
# 17/17 [==============================] - 0s 16ms/step - loss: 0.5535 - val_loss: 0.8778
# Epoch 35/250
# 17/17 [==============================] - 0s 15ms/step - loss: 0.5485 - val_loss: 0.8730
# Epoch 36/250
# 17/17 [==============================] - 0s 16ms/step - loss: 0.5418 - val_loss: 0.8729
# Epoch 37/250
# 17/17 [==============================] - 0s 19ms/step - loss: 0.5382 - val_loss: 0.8799
# Epoch 38/250
# 17/17 [==============================] - 0s 17ms/step - loss: 0.5374 - val_loss: 0.8884
# Epoch 39/250
# 17/17 [==============================] - 0s 15ms/step - loss: 0.5383 - val_loss: 0.8864
# Epoch 40/250
# 17/17 [==============================] - 0s 15ms/step - loss: 0.5349 - val_loss: 0.8851
# Epoch 41/250
# 17/17 [==============================] - 0s 16ms/step - loss: 0.5304 - val_loss: 0.8863
# Epoch 42/250
# 17/17 [==============================] - 0s 16ms/step - loss: 0.5272 - val_loss: 0.8826
# Epoch 43/250
# 17/17 [==============================] - 0s 15ms/step - loss: 0.5247 - val_loss: 0.8897
# Epoch 44/250
# 17/17 [==============================] - 0s 14ms/step - loss: 0.5230 - val_loss: 0.8922
# Epoch 45/250
# 17/17 [==============================] - 0s 21ms/step - loss: 0.5182 - val_loss: 0.8929
# Epoch 46/250
# 17/17 [==============================] - 0s 14ms/step - loss: 0.5125 - val_loss: 0.8923
# Epoch 47/250
# 17/17 [==============================] - 0s 14ms/step - loss: 0.5107 - val_loss: 0.8940
# Epoch 48/250
# 17/17 [==============================] - 0s 15ms/step - loss: 0.5085 - val_loss: 0.8964
# Epoch 49/250
# 17/17 [==============================] - 0s 14ms/step - loss: 0.5053 - val_loss: 0.8935
# Epoch 50/250
# 17/17 [==============================] - 0s 15ms/step - loss: 0.5044 - val_loss: 0.8976
# Epoch 51/250
# 17/17 [==============================] - 0s 15ms/step - loss: 0.5045 - val_loss: 0.8959
# Epoch 52/250
# 17/17 [==============================] - 0s 15ms/step - loss: 0.5034 - val_loss: 0.8953
# Epoch 53/250
# 17/17 [==============================] - 0s 15ms/step - loss: 0.4993 - val_loss: 0.8984
# Epoch 54/250
# 17/17 [==============================] - 0s 15ms/step - loss: 0.4969 - val_loss: 0.9029
# Epoch 55/250
# 17/17 [==============================] - 0s 16ms/step - loss: 0.4943 - val_loss: 0.8977
# Epoch 56/250
# 17/17 [==============================] - 0s 16ms/step - loss: 0.4924 - val_loss: 0.9044
# Epoch 57/250
# 17/17 [==============================] - 0s 22ms/step - loss: 0.4921 - val_loss: 0.9071
# Epoch 58/250
# 17/17 [==============================] - 0s 15ms/step - loss: 0.4913 - val_loss: 0.9072
# Epoch 59/250
# 17/17 [==============================] - 0s 14ms/step - loss: 0.4914 - val_loss: 0.9042
# Epoch 60/250
# 17/17 [==============================] - 0s 16ms/step - loss: 0.4885 - val_loss: 0.9106
# Epoch 61/250
# 17/17 [==============================] - 0s 17ms/step - loss: 0.4876 - val_loss: 0.9043
# Epoch 62/250
# 17/17 [==============================] - 0s 16ms/step - loss: 0.4861 - val_loss: 0.9100
# Epoch 63/250
# 17/17 [==============================] - 0s 14ms/step - loss: 0.4837 - val_loss: 0.9112
# Epoch 64/250
# 17/17 [==============================] - 0s 16ms/step - loss: 0.4823 - val_loss: 0.9156
# Epoch 65/250
# 17/17 [==============================] - 0s 17ms/step - loss: 0.4816 - val_loss: 0.9093
# Epoch 66/250
# 17/17 [==============================] - 0s 15ms/step - loss: 0.4807 - val_loss: 0.9197
# Epoch 67/250
# 17/17 [==============================] - 0s 15ms/step - loss: 0.4786 - val_loss: 0.9135
# Epoch 68/250
# 17/17 [==============================] - 0s 15ms/step - loss: 0.4764 - val_loss: 0.9117
# Epoch 69/250
# 17/17 [==============================] - 0s 16ms/step - loss: 0.4745 - val_loss: 0.9222
# Epoch 70/250
# 17/17 [==============================] - 0s 15ms/step - loss: 0.4727 - val_loss: 0.9140
# Epoch 71/250
# 17/17 [==============================] - 0s 18ms/step - loss: 0.4699 - val_loss: 0.9243
# Epoch 72/250
# 17/17 [==============================] - 0s 25ms/step - loss: 0.4703 - val_loss: 0.9208
# Epoch 73/250
# 17/17 [==============================] - 0s 22ms/step - loss: 0.4703 - val_loss: 0.9240
# Epoch 74/250
# 17/17 [==============================] - 0s 20ms/step - loss: 0.4704 - val_loss: 0.9197
# Epoch 75/250
# 17/17 [==============================] - 0s 19ms/step - loss: 0.4721 - val_loss: 0.9256
# Epoch 76/250
# 17/17 [==============================] - 0s 17ms/step - loss: 0.4711 - val_loss: 0.9272
# Epoch 77/250
# 17/17 [==============================] - 0s 16ms/step - loss: 0.4707 - val_loss: 0.9230
# Epoch 78/250
# 17/17 [==============================] - 0s 16ms/step - loss: 0.4685 - val_loss: 0.9312
# Epoch 79/250
# 17/17 [==============================] - 0s 16ms/step - loss: 0.4689 - val_loss: 0.9237
# Epoch 80/250
# 17/17 [==============================] - 0s 15ms/step - loss: 0.4657 - val_loss: 0.9259
# Epoch 81/250
# 17/17 [==============================] - 0s 15ms/step - loss: 0.4651 - val_loss: 0.9300
# Epoch 82/250
# 17/17 [==============================] - 0s 15ms/step - loss: 0.4629 - val_loss: 0.9278
# Epoch 83/250
# 17/17 [==============================] - 0s 16ms/step - loss: 0.4598 - val_loss: 0.9312
# Epoch 84/250
# 17/17 [==============================] - 0s 14ms/step - loss: 0.4588 - val_loss: 0.9311
# Epoch 85/250
# 17/17 [==============================] - 0s 22ms/step - loss: 0.4621 - val_loss: 0.9352
# Epoch 86/250
# 17/17 [==============================] - 0s 20ms/step - loss: 0.4614 - val_loss: 0.9348
# Epoch 87/250
# 17/17 [==============================] - 0s 15ms/step - loss: 0.4628 - val_loss: 0.9351
# Epoch 88/250
# 17/17 [==============================] - 0s 14ms/step - loss: 0.4623 - val_loss: 0.9375
# Epoch 89/250
# 17/17 [==============================] - 0s 14ms/step - loss: 0.4633 - val_loss: 0.9324
# Epoch 90/250
# 17/17 [==============================] - 0s 14ms/step - loss: 0.4646 - val_loss: 0.9403
# Epoch 91/250
# 17/17 [==============================] - 0s 14ms/step - loss: 0.4628 - val_loss: 0.9375
# Epoch 92/250
# 17/17 [==============================] - 0s 15ms/step - loss: 0.4600 - val_loss: 0.9433
# Epoch 93/250
# 17/17 [==============================] - 0s 14ms/step - loss: 0.4581 - val_loss: 0.9415
# Epoch 94/250
# 17/17 [==============================] - 0s 17ms/step - loss: 0.4572 - val_loss: 0.9398
# Epoch 95/250
# 17/17 [==============================] - 0s 17ms/step - loss: 0.4552 - val_loss: 0.9464
# Epoch 96/250
# 17/17 [==============================] - 0s 15ms/step - loss: 0.4576 - val_loss: 0.9413
# Epoch 97/250
# 17/17 [==============================] - 0s 16ms/step - loss: 0.4564 - val_loss: 0.9458
# Epoch 98/250
# 17/17 [==============================] - 0s 16ms/step - loss: 0.4546 - val_loss: 0.9417
# Epoch 99/250
# 17/17 [==============================] - 0s 22ms/step - loss: 0.4554 - val_loss: 0.9467
# Epoch 100/250
# 17/17 [==============================] - 0s 16ms/step - loss: 0.4534 - val_loss: 0.9478
# Epoch 101/250
# 17/17 [==============================] - 0s 14ms/step - loss: 0.4532 - val_loss: 0.9431
# Epoch 102/250
# 17/17 [==============================] - 0s 16ms/step - loss: 0.4514 - val_loss: 0.9491
# Epoch 103/250
# 17/17 [==============================] - 0s 16ms/step - loss: 0.4494 - val_loss: 0.9426
# Epoch 104/250
# 17/17 [==============================] - 0s 15ms/step - loss: 0.4492 - val_loss: 0.9506
# Epoch 105/250
# 17/17 [==============================] - 0s 15ms/step - loss: 0.4490 - val_loss: 0.9469
# Epoch 106/250
# 17/17 [==============================] - 0s 16ms/step - loss: 0.4500 - val_loss: 0.9486
# Epoch 107/250
# 17/17 [==============================] - 0s 18ms/step - loss: 0.4492 - val_loss: 0.9484
# Epoch 108/250
# 17/17 [==============================] - 0s 20ms/step - loss: 0.4486 - val_loss: 0.9483
# Epoch 109/250
# 17/17 [==============================] - 0s 16ms/step - loss: 0.4479 - val_loss: 0.9531
# Epoch 110/250
# 17/17 [==============================] - 0s 17ms/step - loss: 0.4476 - val_loss: 0.9487
# Epoch 111/250
# 17/17 [==============================] - 0s 15ms/step - loss: 0.4497 - val_loss: 0.9513
# Epoch 112/250
# 17/17 [==============================] - 0s 15ms/step - loss: 0.4486 - val_loss: 0.9550
# Epoch 113/250
# 17/17 [==============================] - 0s 20ms/step - loss: 0.4462 - val_loss: 0.9511
# Epoch 114/250
# 17/17 [==============================] - 0s 16ms/step - loss: 0.4439 - val_loss: 0.9572
# Epoch 115/250
# 17/17 [==============================] - 0s 15ms/step - loss: 0.4424 - val_loss: 0.9564
# Epoch 116/250
# 17/17 [==============================] - 0s 15ms/step - loss: 0.4406 - val_loss: 0.9524
# Epoch 117/250
# 17/17 [==============================] - 0s 18ms/step - loss: 0.4400 - val_loss: 0.9544
# Epoch 118/250
# 17/17 [==============================] - 0s 19ms/step - loss: 0.4381 - val_loss: 0.9542
# Epoch 119/250
# 17/17 [==============================] - 0s 20ms/step - loss: 0.4372 - val_loss: 0.9578
# Epoch 120/250
# 17/17 [==============================] - 0s 17ms/step - loss: 0.4387 - val_loss: 0.9557
# Epoch 121/250
# 17/17 [==============================] - 0s 15ms/step - loss: 0.4376 - val_loss: 0.9636
# Epoch 122/250
# 17/17 [==============================] - 0s 21ms/step - loss: 0.4381 - val_loss: 0.9563
# Epoch 123/250
# 17/17 [==============================] - 0s 18ms/step - loss: 0.4368 - val_loss: 0.9562
# Epoch 124/250
# 17/17 [==============================] - 0s 16ms/step - loss: 0.4372 - val_loss: 0.9673
# Epoch 125/250
# 17/17 [==============================] - 0s 25ms/step - loss: 0.4387 - val_loss: 0.9583
# Epoch 126/250
# 17/17 [==============================] - 0s 19ms/step - loss: 0.4382 - val_loss: 0.9602
# Epoch 127/250
# 17/17 [==============================] - 0s 19ms/step - loss: 0.4388 - val_loss: 0.9579
# Epoch 128/250
# 17/17 [==============================] - 0s 17ms/step - loss: 0.4408 - val_loss: 0.9672
# Epoch 129/250
# 17/17 [==============================] - 0s 17ms/step - loss: 0.4404 - val_loss: 0.9586
# Epoch 130/250
# 17/17 [==============================] - 0s 17ms/step - loss: 0.4434 - val_loss: 0.9697
# Epoch 131/250
# 17/17 [==============================] - 0s 19ms/step - loss: 0.4478 - val_loss: 0.9600
# Epoch 132/250
# 17/17 [==============================] - 0s 20ms/step - loss: 0.4446 - val_loss: 0.9642
# Epoch 133/250
# 17/17 [==============================] - 0s 20ms/step - loss: 0.4440 - val_loss: 0.9560
# Epoch 134/250
# 17/17 [==============================] - 0s 22ms/step - loss: 0.4411 - val_loss: 0.9648
# Epoch 135/250
# 17/17 [==============================] - 0s 22ms/step - loss: 0.4412 - val_loss: 0.9589
# Epoch 136/250
# 17/17 [==============================] - 0s 19ms/step - loss: 0.4422 - val_loss: 0.9621
# Epoch 137/250
# 17/17 [==============================] - 0s 25ms/step - loss: 0.4378 - val_loss: 0.9659
# Epoch 138/250
# 17/17 [==============================] - 0s 19ms/step - loss: 0.4353 - val_loss: 0.9608
# Epoch 139/250
# 17/17 [==============================] - 0s 21ms/step - loss: 0.4338 - val_loss: 0.9625
# Epoch 140/250
# 17/17 [==============================] - 0s 17ms/step - loss: 0.4342 - val_loss: 0.9780
# Epoch 141/250
# 17/17 [==============================] - 0s 16ms/step - loss: 0.4323 - val_loss: 0.9661
# Epoch 142/250
# 17/17 [==============================] - 0s 17ms/step - loss: 0.4311 - val_loss: 0.9671
# Epoch 143/250
# 17/17 [==============================] - 0s 17ms/step - loss: 0.4302 - val_loss: 0.9707
# Epoch 144/250
# 17/17 [==============================] - 0s 19ms/step - loss: 0.4290 - val_loss: 0.9713
# Epoch 145/250
# 17/17 [==============================] - 0s 18ms/step - loss: 0.4289 - val_loss: 0.9681
# Epoch 146/250
# 17/17 [==============================] - 0s 18ms/step - loss: 0.4297 - val_loss: 0.9772
# Epoch 147/250
# 17/17 [==============================] - 0s 18ms/step - loss: 0.4292 - val_loss: 0.9721
# Epoch 148/250
# 17/17 [==============================] - 0s 19ms/step - loss: 0.4297 - val_loss: 0.9721
# Epoch 149/250
# 17/17 [==============================] - 0s 25ms/step - loss: 0.4317 - val_loss: 0.9686
# Epoch 150/250
# 17/17 [==============================] - 0s 24ms/step - loss: 0.4334 - val_loss: 0.9765
# Epoch 151/250
# 17/17 [==============================] - 0s 16ms/step - loss: 0.4358 - val_loss: 0.9686
# Epoch 152/250
# 17/17 [==============================] - 0s 18ms/step - loss: 0.4365 - val_loss: 0.9758
# Epoch 153/250
# 17/17 [==============================] - 0s 17ms/step - loss: 0.4361 - val_loss: 0.9728
# Epoch 154/250
# 17/17 [==============================] - 0s 19ms/step - loss: 0.4355 - val_loss: 0.9729
# Epoch 155/250
# 17/17 [==============================] - 0s 14ms/step - loss: 0.4301 - val_loss: 0.9764
# Epoch 156/250
# 17/17 [==============================] - 0s 15ms/step - loss: 0.4286 - val_loss: 0.9781
# Epoch 157/250
# 17/17 [==============================] - 0s 15ms/step - loss: 0.4275 - val_loss: 0.9764
# Epoch 158/250
# 17/17 [==============================] - 0s 14ms/step - loss: 0.4274 - val_loss: 0.9778
# Epoch 159/250
# 17/17 [==============================] - 0s 14ms/step - loss: 0.4265 - val_loss: 0.9734
# Epoch 160/250
# 17/17 [==============================] - 0s 16ms/step - loss: 0.4282 - val_loss: 0.9791
# Epoch 161/250
# 17/17 [==============================] - 0s 22ms/step - loss: 0.4286 - val_loss: 0.9793
# Epoch 162/250
# 17/17 [==============================] - 0s 18ms/step - loss: 0.4299 - val_loss: 0.9789
# Epoch 163/250
# 17/17 [==============================] - 0s 17ms/step - loss: 0.4296 - val_loss: 0.9714
# Epoch 164/250
# 17/17 [==============================] - 0s 18ms/step - loss: 0.4295 - val_loss: 0.9817
# Epoch 165/250
# 17/17 [==============================] - 0s 15ms/step - loss: 0.4273 - val_loss: 0.9705
# Epoch 166/250
# 17/17 [==============================] - 0s 16ms/step - loss: 0.4278 - val_loss: 0.9771
# Epoch 167/250
# 17/17 [==============================] - 0s 18ms/step - loss: 0.4281 - val_loss: 0.9788
# Epoch 168/250
# 17/17 [==============================] - 0s 15ms/step - loss: 0.4281 - val_loss: 0.9744
# Epoch 169/250
# 17/17 [==============================] - 0s 16ms/step - loss: 0.4268 - val_loss: 0.9792
# Epoch 170/250
# 17/17 [==============================] - 0s 17ms/step - loss: 0.4265 - val_loss: 0.9769
# Epoch 171/250
# 17/17 [==============================] - 0s 17ms/step - loss: 0.4265 - val_loss: 0.9807
# Epoch 172/250
# 17/17 [==============================] - 0s 15ms/step - loss: 0.4276 - val_loss: 0.9797
# Epoch 173/250
# 17/17 [==============================] - 0s 24ms/step - loss: 0.4270 - val_loss: 0.9843
# Epoch 174/250
# 17/17 [==============================] - 0s 21ms/step - loss: 0.4250 - val_loss: 0.9837
# Epoch 175/250
# 17/17 [==============================] - 0s 15ms/step - loss: 0.4223 - val_loss: 0.9842
# Epoch 176/250
# 17/17 [==============================] - 0s 15ms/step - loss: 0.4236 - val_loss: 0.9785
# Epoch 177/250
# 17/17 [==============================] - 0s 14ms/step - loss: 0.4222 - val_loss: 0.9872
# Epoch 178/250
# 17/17 [==============================] - 0s 16ms/step - loss: 0.4212 - val_loss: 0.9836
# Epoch 179/250
# 17/17 [==============================] - 0s 15ms/step - loss: 0.4220 - val_loss: 0.9849
# Epoch 180/250
# 17/17 [==============================] - 0s 16ms/step - loss: 0.4242 - val_loss: 0.9778
# Epoch 181/250
# 17/17 [==============================] - 0s 14ms/step - loss: 0.4265 - val_loss: 0.9847
# Epoch 182/250
# 17/17 [==============================] - 0s 16ms/step - loss: 0.4249 - val_loss: 0.9825
# Epoch 183/250
# 17/17 [==============================] - 0s 19ms/step - loss: 0.4258 - val_loss: 0.9801
# Epoch 184/250
# 17/17 [==============================] - 0s 18ms/step - loss: 0.4289 - val_loss: 0.9855
# Epoch 185/250
# 17/17 [==============================] - 0s 26ms/step - loss: 0.4284 - val_loss: 0.9782
# Epoch 186/250
# 17/17 [==============================] - 0s 16ms/step - loss: 0.4289 - val_loss: 0.9893
# Epoch 187/250
# 17/17 [==============================] - 0s 17ms/step - loss: 0.4255 - val_loss: 0.9792
# Epoch 188/250
# 17/17 [==============================] - 0s 16ms/step - loss: 0.4266 - val_loss: 0.9829
# Epoch 189/250
# 17/17 [==============================] - 0s 17ms/step - loss: 0.4215 - val_loss: 0.9829
# Epoch 190/250
# 17/17 [==============================] - 0s 17ms/step - loss: 0.4191 - val_loss: 0.9799
# Epoch 191/250
# 17/17 [==============================] - 0s 17ms/step - loss: 0.4197 - val_loss: 0.9929
# Epoch 192/250
# 17/17 [==============================] - 0s 17ms/step - loss: 0.4196 - val_loss: 0.9834
# Epoch 193/250
# 17/17 [==============================] - 0s 15ms/step - loss: 0.4188 - val_loss: 0.9898
# Epoch 194/250
# 17/17 [==============================] - 0s 16ms/step - loss: 0.4193 - val_loss: 0.9870
# Epoch 195/250
# 17/17 [==============================] - 0s 18ms/step - loss: 0.4199 - val_loss: 0.9836
# Epoch 196/250
# 17/17 [==============================] - 0s 16ms/step - loss: 0.4193 - val_loss: 0.9868
# Epoch 197/250
# 17/17 [==============================] - 0s 22ms/step - loss: 0.4193 - val_loss: 0.9867
# Epoch 198/250
# 17/17 [==============================] - 0s 16ms/step - loss: 0.4180 - val_loss: 0.9887
# Epoch 199/250
# 17/17 [==============================] - 0s 16ms/step - loss: 0.4184 - val_loss: 0.9871
# Epoch 200/250
# 17/17 [==============================] - 0s 15ms/step - loss: 0.4174 - val_loss: 0.9874
# Epoch 201/250
# 17/17 [==============================] - 0s 15ms/step - loss: 0.4183 - val_loss: 0.9884
# Epoch 202/250
# 17/17 [==============================] - 0s 17ms/step - loss: 0.4179 - val_loss: 0.9898
# Epoch 203/250
# 17/17 [==============================] - 0s 15ms/step - loss: 0.4188 - val_loss: 0.9883
# Epoch 204/250
# 17/17 [==============================] - 0s 16ms/step - loss: 0.4196 - val_loss: 0.9926
# Epoch 205/250
# 17/17 [==============================] - 0s 16ms/step - loss: 0.4232 - val_loss: 0.9840
# Epoch 206/250
# 17/17 [==============================] - 0s 19ms/step - loss: 0.4224 - val_loss: 0.9887
# Epoch 207/250
# 17/17 [==============================] - 0s 15ms/step - loss: 0.4237 - val_loss: 0.9817
# Epoch 208/250
# 17/17 [==============================] - 0s 14ms/step - loss: 0.4233 - val_loss: 0.9867
# Epoch 209/250
# 17/17 [==============================] - 0s 23ms/step - loss: 0.4199 - val_loss: 0.9910
# Epoch 210/250
# 17/17 [==============================] - 0s 20ms/step - loss: 0.4202 - val_loss: 0.9869
# Epoch 211/250
# 17/17 [==============================] - 0s 14ms/step - loss: 0.4200 - val_loss: 0.9896
# Epoch 212/250
# 17/17 [==============================] - 0s 15ms/step - loss: 0.4195 - val_loss: 0.9942
# Epoch 213/250
# 17/17 [==============================] - 0s 15ms/step - loss: 0.4189 - val_loss: 0.9936
# Epoch 214/250
# 17/17 [==============================] - 0s 14ms/step - loss: 0.4186 - val_loss: 0.9844
# Epoch 215/250
# 17/17 [==============================] - 0s 15ms/step - loss: 0.4189 - val_loss: 0.9965
# Epoch 216/250
# 17/17 [==============================] - 0s 15ms/step - loss: 0.4188 - val_loss: 0.9872
# Epoch 217/250
# 17/17 [==============================] - 0s 20ms/step - loss: 0.4180 - val_loss: 0.9947
# Epoch 218/250
# 17/17 [==============================] - 0s 18ms/step - loss: 0.4187 - val_loss: 0.9937
# Epoch 219/250
# 17/17 [==============================] - 0s 17ms/step - loss: 0.4169 - val_loss: 0.9896
# Epoch 220/250
# 17/17 [==============================] - 0s 27ms/step - loss: 0.4166 - val_loss: 0.9953
# Epoch 221/250
# 17/17 [==============================] - 0s 15ms/step - loss: 0.4164 - val_loss: 0.9944
# Epoch 222/250
# 17/17 [==============================] - 0s 15ms/step - loss: 0.4164 - val_loss: 0.9904
# Epoch 223/250
# 17/17 [==============================] - 0s 19ms/step - loss: 0.4168 - val_loss: 0.9912
# Epoch 224/250
# 17/17 [==============================] - 0s 16ms/step - loss: 0.4176 - val_loss: 0.9898
# Epoch 225/250
# 17/17 [==============================] - 0s 24ms/step - loss: 0.4175 - val_loss: 0.9866
# Epoch 226/250
# 17/17 [==============================] - 0s 18ms/step - loss: 0.4166 - val_loss: 0.9933
# Epoch 227/250
# 17/17 [==============================] - 0s 17ms/step - loss: 0.4172 - val_loss: 0.9927
# Epoch 228/250
# 17/17 [==============================] - 0s 17ms/step - loss: 0.4157 - val_loss: 0.9860
# Epoch 229/250
# 17/17 [==============================] - 0s 18ms/step - loss: 0.4154 - val_loss: 0.9892
# Epoch 230/250
# 17/17 [==============================] - 1s 44ms/step - loss: 0.4153 - val_loss: 0.9954
# Epoch 231/250
# 17/17 [==============================] - 1s 43ms/step - loss: 0.4140 - val_loss: 0.9963
# Epoch 232/250
# 17/17 [==============================] - 1s 31ms/step - loss: 0.4146 - val_loss: 0.9949
# Epoch 233/250
# 17/17 [==============================] - 1s 34ms/step - loss: 0.4143 - val_loss: 0.9926
# Epoch 234/250
# 17/17 [==============================] - 0s 26ms/step - loss: 0.4137 - val_loss: 1.0006
# Epoch 235/250
# 17/17 [==============================] - 0s 20ms/step - loss: 0.4150 - val_loss: 0.9899
# Epoch 236/250
# 17/17 [==============================] - 0s 20ms/step - loss: 0.4153 - val_loss: 0.9986
# Epoch 237/250
# 17/17 [==============================] - 0s 19ms/step - loss: 0.4142 - val_loss: 0.9898
# Epoch 238/250
# 17/17 [==============================] - 1s 33ms/step - loss: 0.4138 - val_loss: 0.9944
# Epoch 239/250
# 17/17 [==============================] - 1s 34ms/step - loss: 0.4136 - val_loss: 0.9945
# Epoch 240/250
# 17/17 [==============================] - 0s 27ms/step - loss: 0.4145 - val_loss: 0.9890
# Epoch 241/250
# 17/17 [==============================] - 0s 22ms/step - loss: 0.4132 - val_loss: 0.9901
# Epoch 242/250
# 17/17 [==============================] - 0s 26ms/step - loss: 0.4120 - val_loss: 0.9976
# Epoch 243/250
# 17/17 [==============================] - 0s 19ms/step - loss: 0.4115 - val_loss: 0.9934
# Epoch 244/250
# 17/17 [==============================] - 0s 19ms/step - loss: 0.4111 - val_loss: 0.9972
# Epoch 245/250
# 17/17 [==============================] - 0s 18ms/step - loss: 0.4108 - val_loss: 0.9970
# Epoch 246/250
# 17/17 [==============================] - 0s 17ms/step - loss: 0.4120 - val_loss: 0.9903
# Epoch 247/250
# 17/17 [==============================] - 0s 27ms/step - loss: 0.4116 - val_loss: 0.9963
# Epoch 248/250
# 17/17 [==============================] - 0s 20ms/step - loss: 0.4112 - val_loss: 0.9940
# Epoch 249/250
# 17/17 [==============================] - 0s 18ms/step - loss: 0.4115 - val_loss: 1.0016
# Epoch 250/250
# 17/17 [==============================] - 0s 19ms/step - loss: 0.4101 - val_loss: 0.9957
# 17/17 [==============================] - 0s 3ms/step
# 5/5 [==============================] - 0s 2ms/step
# Epoch 1/250
# 17/17 [==============================] - 2s 25ms/step - loss: 22.3542 - accuracy: 0.2201 - val_loss: 5.0708 - val_accuracy: 0.3111
# Epoch 2/250
# 17/17 [==============================] - 0s 7ms/step - loss: 13.7663 - accuracy: 0.3433 - val_loss: 3.2005 - val_accuracy: 0.5407
# Epoch 3/250
# 17/17 [==============================] - 0s 8ms/step - loss: 12.2344 - accuracy: 0.3731 - val_loss: 2.6450 - val_accuracy: 0.5778
# Epoch 4/250
# 17/17 [==============================] - 0s 8ms/step - loss: 8.1283 - accuracy: 0.3843 - val_loss: 2.2100 - val_accuracy: 0.5926
# Epoch 5/250
# 17/17 [==============================] - 0s 6ms/step - loss: 7.0710 - accuracy: 0.4198 - val_loss: 1.9711 - val_accuracy: 0.6148
# Epoch 6/250
# 17/17 [==============================] - 0s 7ms/step - loss: 6.1840 - accuracy: 0.4571 - val_loss: 1.7929 - val_accuracy: 0.6074
# Epoch 7/250
# 17/17 [==============================] - 0s 8ms/step - loss: 4.7608 - accuracy: 0.4683 - val_loss: 1.6710 - val_accuracy: 0.5926
# Epoch 8/250
# 17/17 [==============================] - 0s 6ms/step - loss: 3.8882 - accuracy: 0.4869 - val_loss: 1.4874 - val_accuracy: 0.6000
# Epoch 9/250
# 17/17 [==============================] - 0s 6ms/step - loss: 4.3428 - accuracy: 0.4627 - val_loss: 1.3687 - val_accuracy: 0.6148
# Epoch 10/250
# 17/17 [==============================] - 0s 7ms/step - loss: 3.3106 - accuracy: 0.4646 - val_loss: 1.2993 - val_accuracy: 0.6296
# Epoch 11/250
# 17/17 [==============================] - 0s 7ms/step - loss: 2.8136 - accuracy: 0.5205 - val_loss: 1.2551 - val_accuracy: 0.6444
# Epoch 12/250
# 17/17 [==============================] - 0s 15ms/step - loss: 3.2315 - accuracy: 0.5019 - val_loss: 1.2429 - val_accuracy: 0.6222
# Epoch 13/250
# 17/17 [==============================] - 0s 7ms/step - loss: 2.9889 - accuracy: 0.4590 - val_loss: 1.2331 - val_accuracy: 0.6074
# Epoch 14/250
# 17/17 [==============================] - 0s 6ms/step - loss: 2.4090 - accuracy: 0.4925 - val_loss: 1.2199 - val_accuracy: 0.6148
# Epoch 15/250
# 17/17 [==============================] - 0s 7ms/step - loss: 2.3372 - accuracy: 0.5224 - val_loss: 1.2122 - val_accuracy: 0.6074
# Epoch 16/250
# 17/17 [==============================] - 0s 6ms/step - loss: 2.1503 - accuracy: 0.5224 - val_loss: 1.2000 - val_accuracy: 0.5926
# Epoch 17/250
# 17/17 [==============================] - 0s 6ms/step - loss: 2.0909 - accuracy: 0.5410 - val_loss: 1.1927 - val_accuracy: 0.5926
# Epoch 18/250
# 17/17 [==============================] - 0s 6ms/step - loss: 2.0570 - accuracy: 0.5261 - val_loss: 1.1848 - val_accuracy: 0.5926
# Epoch 19/250
# 17/17 [==============================] - 0s 5ms/step - loss: 1.8282 - accuracy: 0.5261 - val_loss: 1.1781 - val_accuracy: 0.5852
# Epoch 20/250
# 17/17 [==============================] - 0s 6ms/step - loss: 1.6567 - accuracy: 0.5802 - val_loss: 1.1700 - val_accuracy: 0.5852
# Epoch 21/250
# 17/17 [==============================] - 0s 5ms/step - loss: 1.7246 - accuracy: 0.5802 - val_loss: 1.1625 - val_accuracy: 0.5852
# Epoch 22/250
# 17/17 [==============================] - 0s 6ms/step - loss: 1.5875 - accuracy: 0.5560 - val_loss: 1.1569 - val_accuracy: 0.5852
# Epoch 23/250
# 17/17 [==============================] - 0s 6ms/step - loss: 1.4738 - accuracy: 0.5765 - val_loss: 1.1612 - val_accuracy: 0.5778
# Epoch 24/250
# 17/17 [==============================] - 0s 7ms/step - loss: 1.6059 - accuracy: 0.5690 - val_loss: 1.1567 - val_accuracy: 0.5778
# Epoch 25/250
# 17/17 [==============================] - 0s 6ms/step - loss: 1.5948 - accuracy: 0.5690 - val_loss: 1.1540 - val_accuracy: 0.5778
# Epoch 26/250
# 17/17 [==============================] - 0s 6ms/step - loss: 1.4888 - accuracy: 0.5840 - val_loss: 1.1523 - val_accuracy: 0.5778
# Epoch 27/250
# 17/17 [==============================] - 0s 7ms/step - loss: 1.4582 - accuracy: 0.5653 - val_loss: 1.1457 - val_accuracy: 0.5778
# Epoch 28/250
# 17/17 [==============================] - 0s 6ms/step - loss: 1.5183 - accuracy: 0.5746 - val_loss: 1.1444 - val_accuracy: 0.5778
# Epoch 29/250
# 17/17 [==============================] - 0s 7ms/step - loss: 1.3834 - accuracy: 0.5858 - val_loss: 1.1384 - val_accuracy: 0.5778
# Epoch 30/250
# 17/17 [==============================] - 0s 7ms/step - loss: 1.3838 - accuracy: 0.5784 - val_loss: 1.1349 - val_accuracy: 0.5778
# Epoch 31/250
# 17/17 [==============================] - 0s 6ms/step - loss: 1.3257 - accuracy: 0.5970 - val_loss: 1.1414 - val_accuracy: 0.5778
# Epoch 32/250
# 17/17 [==============================] - 0s 8ms/step - loss: 1.2972 - accuracy: 0.5989 - val_loss: 1.1351 - val_accuracy: 0.5778
# Epoch 33/250
# 17/17 [==============================] - 0s 7ms/step - loss: 1.2987 - accuracy: 0.6026 - val_loss: 1.1233 - val_accuracy: 0.5778
# Epoch 34/250
# 17/17 [==============================] - 0s 7ms/step - loss: 1.3046 - accuracy: 0.5784 - val_loss: 1.1144 - val_accuracy: 0.5778
# Epoch 35/250
# 17/17 [==============================] - 0s 7ms/step - loss: 1.4291 - accuracy: 0.6157 - val_loss: 1.1148 - val_accuracy: 0.5778
# Epoch 36/250
# 17/17 [==============================] - 0s 16ms/step - loss: 1.2397 - accuracy: 0.6157 - val_loss: 1.1177 - val_accuracy: 0.5778
# Epoch 37/250
# 17/17 [==============================] - 0s 10ms/step - loss: 1.3374 - accuracy: 0.6045 - val_loss: 1.1143 - val_accuracy: 0.5778
# Epoch 38/250
# 17/17 [==============================] - 0s 7ms/step - loss: 1.2282 - accuracy: 0.5896 - val_loss: 1.1131 - val_accuracy: 0.5778
# Epoch 39/250
# 17/17 [==============================] - 0s 8ms/step - loss: 1.2188 - accuracy: 0.6194 - val_loss: 1.1087 - val_accuracy: 0.5778
# Epoch 40/250
# 17/17 [==============================] - 0s 13ms/step - loss: 1.3213 - accuracy: 0.6231 - val_loss: 1.1105 - val_accuracy: 0.5778
# Epoch 41/250
# 17/17 [==============================] - 0s 7ms/step - loss: 1.2942 - accuracy: 0.6213 - val_loss: 1.1113 - val_accuracy: 0.5704
# Epoch 42/250
# 17/17 [==============================] - 0s 5ms/step - loss: 1.1791 - accuracy: 0.6082 - val_loss: 1.1065 - val_accuracy: 0.5704
# Epoch 43/250
# 17/17 [==============================] - 0s 7ms/step - loss: 1.1951 - accuracy: 0.6175 - val_loss: 1.1039 - val_accuracy: 0.5778
# Epoch 44/250
# 17/17 [==============================] - 0s 5ms/step - loss: 1.1545 - accuracy: 0.6007 - val_loss: 1.1001 - val_accuracy: 0.5778
# Epoch 45/250
# 17/17 [==============================] - 0s 6ms/step - loss: 1.1697 - accuracy: 0.6194 - val_loss: 1.1016 - val_accuracy: 0.5778
# Epoch 46/250
# 17/17 [==============================] - 0s 9ms/step - loss: 1.1782 - accuracy: 0.6045 - val_loss: 1.0998 - val_accuracy: 0.5630
# Epoch 47/250
# 17/17 [==============================] - 0s 7ms/step - loss: 1.1588 - accuracy: 0.5951 - val_loss: 1.1026 - val_accuracy: 0.5704
# Epoch 48/250
# 17/17 [==============================] - 0s 7ms/step - loss: 1.1638 - accuracy: 0.6213 - val_loss: 1.0990 - val_accuracy: 0.5852
# Epoch 49/250
# 17/17 [==============================] - 0s 8ms/step - loss: 1.1825 - accuracy: 0.6362 - val_loss: 1.0965 - val_accuracy: 0.5778
# Epoch 50/250
# 17/17 [==============================] - 0s 8ms/step - loss: 1.1614 - accuracy: 0.6399 - val_loss: 1.0924 - val_accuracy: 0.5852
# Epoch 51/250
# 17/17 [==============================] - 0s 7ms/step - loss: 1.1295 - accuracy: 0.6007 - val_loss: 1.0846 - val_accuracy: 0.5778
# Epoch 52/250
# 17/17 [==============================] - 0s 7ms/step - loss: 1.1820 - accuracy: 0.6119 - val_loss: 1.0799 - val_accuracy: 0.5778
# Epoch 53/250
# 17/17 [==============================] - 0s 7ms/step - loss: 1.1300 - accuracy: 0.6362 - val_loss: 1.0772 - val_accuracy: 0.5852
# Epoch 54/250
# 17/17 [==============================] - 0s 7ms/step - loss: 1.1749 - accuracy: 0.6026 - val_loss: 1.0755 - val_accuracy: 0.5778
# Epoch 55/250
# 17/17 [==============================] - 0s 6ms/step - loss: 1.1366 - accuracy: 0.6213 - val_loss: 1.0752 - val_accuracy: 0.5778
# Epoch 56/250
# 17/17 [==============================] - 0s 7ms/step - loss: 1.0864 - accuracy: 0.6250 - val_loss: 1.0758 - val_accuracy: 0.5778
# Epoch 57/250
# 17/17 [==============================] - 0s 16ms/step - loss: 1.0838 - accuracy: 0.6381 - val_loss: 1.0736 - val_accuracy: 0.5778
# Epoch 58/250
# 17/17 [==============================] - 0s 8ms/step - loss: 1.0793 - accuracy: 0.6343 - val_loss: 1.0761 - val_accuracy: 0.5778
# Epoch 59/250
# 17/17 [==============================] - 0s 7ms/step - loss: 1.1095 - accuracy: 0.6231 - val_loss: 1.0765 - val_accuracy: 0.5778
# Epoch 60/250
# 17/17 [==============================] - 0s 7ms/step - loss: 1.0407 - accuracy: 0.6362 - val_loss: 1.0728 - val_accuracy: 0.5778
# Epoch 61/250
# 17/17 [==============================] - 0s 8ms/step - loss: 1.0674 - accuracy: 0.6381 - val_loss: 1.0726 - val_accuracy: 0.5778
# Epoch 62/250
# 17/17 [==============================] - 0s 7ms/step - loss: 1.1152 - accuracy: 0.6343 - val_loss: 1.0699 - val_accuracy: 0.5778
# Epoch 63/250
# 17/17 [==============================] - 0s 8ms/step - loss: 1.0630 - accuracy: 0.6381 - val_loss: 1.0727 - val_accuracy: 0.5778
# Epoch 64/250
# 17/17 [==============================] - 0s 7ms/step - loss: 1.0227 - accuracy: 0.6493 - val_loss: 1.0717 - val_accuracy: 0.5778
# Epoch 65/250
# 17/17 [==============================] - 0s 9ms/step - loss: 1.0801 - accuracy: 0.6343 - val_loss: 1.0665 - val_accuracy: 0.5778
# Epoch 66/250
# 17/17 [==============================] - 0s 9ms/step - loss: 1.0263 - accuracy: 0.6567 - val_loss: 1.0606 - val_accuracy: 0.5778
# Epoch 67/250
# 17/17 [==============================] - 0s 7ms/step - loss: 1.0051 - accuracy: 0.6306 - val_loss: 1.0584 - val_accuracy: 0.5778
# Epoch 68/250
# 17/17 [==============================] - 0s 10ms/step - loss: 1.1024 - accuracy: 0.6325 - val_loss: 1.0563 - val_accuracy: 0.5778
# Epoch 69/250
# 17/17 [==============================] - 0s 12ms/step - loss: 1.0522 - accuracy: 0.6138 - val_loss: 1.0514 - val_accuracy: 0.5778
# Epoch 70/250
# 17/17 [==============================] - 0s 11ms/step - loss: 0.9894 - accuracy: 0.6343 - val_loss: 1.0478 - val_accuracy: 0.5778
# Epoch 71/250
# 17/17 [==============================] - 0s 9ms/step - loss: 0.9957 - accuracy: 0.6119 - val_loss: 1.0472 - val_accuracy: 0.5778
# Epoch 72/250
# 17/17 [==============================] - 0s 15ms/step - loss: 1.0337 - accuracy: 0.6362 - val_loss: 1.0450 - val_accuracy: 0.5852
# Epoch 73/250
# 17/17 [==============================] - 0s 12ms/step - loss: 0.9969 - accuracy: 0.6455 - val_loss: 1.0470 - val_accuracy: 0.5852
# Epoch 74/250
# 17/17 [==============================] - 0s 28ms/step - loss: 0.9948 - accuracy: 0.6437 - val_loss: 1.0492 - val_accuracy: 0.5852
# Epoch 75/250
# 17/17 [==============================] - 0s 10ms/step - loss: 0.9993 - accuracy: 0.6418 - val_loss: 1.0464 - val_accuracy: 0.5852
# Epoch 76/250
# 17/17 [==============================] - 0s 10ms/step - loss: 1.0676 - accuracy: 0.6362 - val_loss: 1.0453 - val_accuracy: 0.5852
# Epoch 77/250
# 17/17 [==============================] - 0s 10ms/step - loss: 1.0206 - accuracy: 0.6493 - val_loss: 1.0369 - val_accuracy: 0.5852
# Epoch 78/250
# 17/17 [==============================] - 0s 11ms/step - loss: 0.9965 - accuracy: 0.6381 - val_loss: 1.0297 - val_accuracy: 0.5852
# Epoch 79/250
# 17/17 [==============================] - 0s 10ms/step - loss: 1.0389 - accuracy: 0.6399 - val_loss: 1.0346 - val_accuracy: 0.5852
# Epoch 80/250
# 17/17 [==============================] - 0s 8ms/step - loss: 0.9949 - accuracy: 0.6511 - val_loss: 1.0390 - val_accuracy: 0.5852
# Epoch 81/250
# 17/17 [==============================] - 0s 8ms/step - loss: 0.9582 - accuracy: 0.6511 - val_loss: 1.0285 - val_accuracy: 0.5852
# Epoch 82/250
# 17/17 [==============================] - 0s 9ms/step - loss: 0.9740 - accuracy: 0.6455 - val_loss: 1.0250 - val_accuracy: 0.5852
# Epoch 83/250
# 17/17 [==============================] - 0s 8ms/step - loss: 1.0127 - accuracy: 0.6381 - val_loss: 1.0253 - val_accuracy: 0.5852
# Epoch 84/250
# 17/17 [==============================] - 0s 8ms/step - loss: 0.9154 - accuracy: 0.6754 - val_loss: 1.0230 - val_accuracy: 0.5852
# Epoch 85/250
# 17/17 [==============================] - 0s 7ms/step - loss: 1.0307 - accuracy: 0.6343 - val_loss: 1.0202 - val_accuracy: 0.5778
# Epoch 86/250
# 17/17 [==============================] - 0s 8ms/step - loss: 0.9589 - accuracy: 0.6474 - val_loss: 1.0206 - val_accuracy: 0.5778
# Epoch 87/250
# 17/17 [==============================] - 0s 8ms/step - loss: 0.9781 - accuracy: 0.6679 - val_loss: 1.0200 - val_accuracy: 0.5852
# Epoch 88/250
# 17/17 [==============================] - 0s 7ms/step - loss: 0.9937 - accuracy: 0.6437 - val_loss: 1.0193 - val_accuracy: 0.5852
# Epoch 89/250
# 17/17 [==============================] - 0s 6ms/step - loss: 0.9821 - accuracy: 0.6437 - val_loss: 1.0156 - val_accuracy: 0.5852
# Epoch 90/250
# 17/17 [==============================] - 0s 16ms/step - loss: 0.9563 - accuracy: 0.6586 - val_loss: 1.0142 - val_accuracy: 0.5852
# Epoch 91/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.9507 - accuracy: 0.6586 - val_loss: 1.0128 - val_accuracy: 0.5852
# Epoch 92/250
# 17/17 [==============================] - 0s 6ms/step - loss: 0.9305 - accuracy: 0.6493 - val_loss: 1.0052 - val_accuracy: 0.5926
# Epoch 93/250
# 17/17 [==============================] - 0s 8ms/step - loss: 0.8910 - accuracy: 0.6623 - val_loss: 1.0012 - val_accuracy: 0.6000
# Epoch 94/250
# 17/17 [==============================] - 0s 7ms/step - loss: 0.9348 - accuracy: 0.6418 - val_loss: 0.9997 - val_accuracy: 0.5926
# Epoch 95/250
# 17/17 [==============================] - 0s 6ms/step - loss: 1.0117 - accuracy: 0.6381 - val_loss: 0.9991 - val_accuracy: 0.5926
# Epoch 96/250
# 17/17 [==============================] - 0s 6ms/step - loss: 0.9043 - accuracy: 0.6791 - val_loss: 0.9955 - val_accuracy: 0.5852
# Epoch 97/250
# 17/17 [==============================] - 0s 6ms/step - loss: 0.9011 - accuracy: 0.6716 - val_loss: 0.9885 - val_accuracy: 0.6000
# Epoch 98/250
# 17/17 [==============================] - 0s 6ms/step - loss: 0.9631 - accuracy: 0.6530 - val_loss: 0.9916 - val_accuracy: 0.6000
# Epoch 99/250
# 17/17 [==============================] - 0s 14ms/step - loss: 0.9011 - accuracy: 0.6716 - val_loss: 0.9954 - val_accuracy: 0.6074
# Epoch 100/250
# 17/17 [==============================] - 0s 9ms/step - loss: 0.9475 - accuracy: 0.6343 - val_loss: 0.9991 - val_accuracy: 0.6074
# Epoch 101/250
# 17/17 [==============================] - 0s 8ms/step - loss: 0.9375 - accuracy: 0.6604 - val_loss: 0.9943 - val_accuracy: 0.6000
# Epoch 102/250
# 17/17 [==============================] - 0s 7ms/step - loss: 0.8787 - accuracy: 0.6698 - val_loss: 0.9970 - val_accuracy: 0.6000
# Epoch 103/250
# 17/17 [==============================] - 0s 7ms/step - loss: 0.9302 - accuracy: 0.6530 - val_loss: 0.9964 - val_accuracy: 0.6000
# Epoch 104/250
# 17/17 [==============================] - 0s 6ms/step - loss: 0.9198 - accuracy: 0.6735 - val_loss: 0.9989 - val_accuracy: 0.6000
# Epoch 105/250
# 17/17 [==============================] - 0s 6ms/step - loss: 0.9115 - accuracy: 0.6567 - val_loss: 0.9982 - val_accuracy: 0.6074
# Epoch 106/250
# 17/17 [==============================] - 0s 7ms/step - loss: 0.8800 - accuracy: 0.6754 - val_loss: 0.9941 - val_accuracy: 0.6074
# Epoch 107/250
# 17/17 [==============================] - 0s 9ms/step - loss: 0.9235 - accuracy: 0.6754 - val_loss: 0.9945 - val_accuracy: 0.6074
# Epoch 108/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.9078 - accuracy: 0.6828 - val_loss: 0.9971 - val_accuracy: 0.6074
# Epoch 109/250
# 17/17 [==============================] - 0s 16ms/step - loss: 0.8673 - accuracy: 0.6586 - val_loss: 0.9924 - val_accuracy: 0.6074
# Epoch 110/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.9017 - accuracy: 0.6810 - val_loss: 0.9865 - val_accuracy: 0.6074
# Epoch 111/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.9261 - accuracy: 0.6735 - val_loss: 0.9907 - val_accuracy: 0.6074
# Epoch 112/250
# 17/17 [==============================] - 0s 6ms/step - loss: 0.9332 - accuracy: 0.6735 - val_loss: 0.9978 - val_accuracy: 0.6074
# Epoch 113/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.8958 - accuracy: 0.6604 - val_loss: 0.9987 - val_accuracy: 0.6148
# Epoch 114/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.8769 - accuracy: 0.6810 - val_loss: 0.9974 - val_accuracy: 0.6074
# Epoch 115/250
# 17/17 [==============================] - 0s 4ms/step - loss: 0.8718 - accuracy: 0.6642 - val_loss: 0.9954 - val_accuracy: 0.6148
# Epoch 116/250
# 17/17 [==============================] - 0s 4ms/step - loss: 0.8828 - accuracy: 0.6754 - val_loss: 0.9940 - val_accuracy: 0.6148
# Epoch 117/250
# 17/17 [==============================] - 0s 4ms/step - loss: 0.8952 - accuracy: 0.6735 - val_loss: 0.9859 - val_accuracy: 0.6148
# Epoch 118/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.8806 - accuracy: 0.6549 - val_loss: 0.9888 - val_accuracy: 0.6148
# Epoch 119/250
# 17/17 [==============================] - 0s 6ms/step - loss: 0.9027 - accuracy: 0.6623 - val_loss: 0.9928 - val_accuracy: 0.6148
# Epoch 120/250
# 17/17 [==============================] - 0s 6ms/step - loss: 0.8601 - accuracy: 0.6866 - val_loss: 0.9946 - val_accuracy: 0.6074
# Epoch 121/250
# 17/17 [==============================] - 0s 7ms/step - loss: 0.9612 - accuracy: 0.6530 - val_loss: 0.9899 - val_accuracy: 0.6074
# Epoch 122/250
# 17/17 [==============================] - 0s 13ms/step - loss: 0.8764 - accuracy: 0.6716 - val_loss: 0.9890 - val_accuracy: 0.6148
# Epoch 123/250
# 17/17 [==============================] - 0s 6ms/step - loss: 0.8899 - accuracy: 0.6791 - val_loss: 0.9870 - val_accuracy: 0.6148
# Epoch 124/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.8753 - accuracy: 0.6810 - val_loss: 0.9903 - val_accuracy: 0.6074
# Epoch 125/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.8436 - accuracy: 0.6847 - val_loss: 0.9943 - val_accuracy: 0.6148
# Epoch 126/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.8692 - accuracy: 0.6604 - val_loss: 0.9877 - val_accuracy: 0.6148
# Epoch 127/250
# 17/17 [==============================] - 0s 7ms/step - loss: 0.8241 - accuracy: 0.6847 - val_loss: 0.9891 - val_accuracy: 0.6148
# Epoch 128/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.8106 - accuracy: 0.6754 - val_loss: 0.9938 - val_accuracy: 0.6148
# Epoch 129/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.8681 - accuracy: 0.6772 - val_loss: 0.9928 - val_accuracy: 0.6148
# Epoch 130/250
# 17/17 [==============================] - 0s 14ms/step - loss: 0.8522 - accuracy: 0.6716 - val_loss: 0.9832 - val_accuracy: 0.6148
# Epoch 131/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.8455 - accuracy: 0.6903 - val_loss: 0.9833 - val_accuracy: 0.6148
# Epoch 132/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.8696 - accuracy: 0.6884 - val_loss: 0.9825 - val_accuracy: 0.6148
# Epoch 133/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.8172 - accuracy: 0.6978 - val_loss: 0.9787 - val_accuracy: 0.6148
# Epoch 134/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.8426 - accuracy: 0.6716 - val_loss: 0.9775 - val_accuracy: 0.6148
# Epoch 135/250
# 17/17 [==============================] - 0s 4ms/step - loss: 0.8350 - accuracy: 0.6642 - val_loss: 0.9849 - val_accuracy: 0.6148
# Epoch 136/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.8239 - accuracy: 0.6772 - val_loss: 0.9888 - val_accuracy: 0.6222
# Epoch 137/250
# 17/17 [==============================] - 0s 4ms/step - loss: 0.8299 - accuracy: 0.6866 - val_loss: 0.9865 - val_accuracy: 0.6148
# Epoch 138/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.8387 - accuracy: 0.6847 - val_loss: 0.9855 - val_accuracy: 0.6148
# Epoch 139/250
# 17/17 [==============================] - 0s 4ms/step - loss: 0.8278 - accuracy: 0.6940 - val_loss: 0.9845 - val_accuracy: 0.6148
# Epoch 140/250
# 17/17 [==============================] - 0s 4ms/step - loss: 0.8255 - accuracy: 0.6959 - val_loss: 0.9857 - val_accuracy: 0.6074
# Epoch 141/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.8065 - accuracy: 0.6847 - val_loss: 0.9923 - val_accuracy: 0.6148
# Epoch 142/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.8406 - accuracy: 0.6847 - val_loss: 1.0038 - val_accuracy: 0.6148
# Epoch 143/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.8426 - accuracy: 0.6922 - val_loss: 0.9905 - val_accuracy: 0.6148
# Epoch 144/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.7618 - accuracy: 0.7201 - val_loss: 0.9862 - val_accuracy: 0.6148
# Epoch 145/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.7637 - accuracy: 0.7127 - val_loss: 0.9837 - val_accuracy: 0.6074
# Epoch 146/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.8148 - accuracy: 0.6847 - val_loss: 0.9771 - val_accuracy: 0.6148
# Epoch 147/250
# 17/17 [==============================] - 0s 4ms/step - loss: 0.7695 - accuracy: 0.7052 - val_loss: 0.9775 - val_accuracy: 0.6148
# Epoch 148/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.7951 - accuracy: 0.7071 - val_loss: 0.9682 - val_accuracy: 0.6148
# Epoch 149/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.8185 - accuracy: 0.6828 - val_loss: 0.9699 - val_accuracy: 0.6222
# Epoch 150/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.7766 - accuracy: 0.7127 - val_loss: 0.9793 - val_accuracy: 0.6222
# Epoch 151/250
# 17/17 [==============================] - 0s 4ms/step - loss: 0.8213 - accuracy: 0.6996 - val_loss: 0.9801 - val_accuracy: 0.6222
# Epoch 152/250
# 17/17 [==============================] - 0s 16ms/step - loss: 0.7648 - accuracy: 0.7071 - val_loss: 0.9783 - val_accuracy: 0.6222
# Epoch 153/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.7919 - accuracy: 0.6716 - val_loss: 0.9764 - val_accuracy: 0.6222
# Epoch 154/250
# 17/17 [==============================] - 0s 6ms/step - loss: 0.8082 - accuracy: 0.6772 - val_loss: 0.9781 - val_accuracy: 0.6222
# Epoch 155/250
# 17/17 [==============================] - 0s 6ms/step - loss: 0.7475 - accuracy: 0.7257 - val_loss: 0.9858 - val_accuracy: 0.6222
# Epoch 156/250
# 17/17 [==============================] - 0s 6ms/step - loss: 0.8036 - accuracy: 0.6810 - val_loss: 0.9832 - val_accuracy: 0.6148
# Epoch 157/250
# 17/17 [==============================] - 0s 7ms/step - loss: 0.7514 - accuracy: 0.6978 - val_loss: 0.9814 - val_accuracy: 0.6222
# Epoch 158/250
# 17/17 [==============================] - 0s 4ms/step - loss: 0.7529 - accuracy: 0.7090 - val_loss: 0.9712 - val_accuracy: 0.6148
# Epoch 159/250
# 17/17 [==============================] - 0s 4ms/step - loss: 0.8092 - accuracy: 0.7015 - val_loss: 0.9667 - val_accuracy: 0.6222
# Epoch 160/250
# 17/17 [==============================] - 0s 4ms/step - loss: 0.8166 - accuracy: 0.6940 - val_loss: 0.9588 - val_accuracy: 0.6222
# Epoch 161/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.7500 - accuracy: 0.6940 - val_loss: 0.9638 - val_accuracy: 0.6222
# Epoch 162/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.7547 - accuracy: 0.7052 - val_loss: 0.9630 - val_accuracy: 0.6222
# Epoch 163/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.7570 - accuracy: 0.7034 - val_loss: 0.9539 - val_accuracy: 0.6148
# Epoch 164/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.7728 - accuracy: 0.6996 - val_loss: 0.9542 - val_accuracy: 0.6222
# Epoch 165/250
# 17/17 [==============================] - 0s 4ms/step - loss: 0.7734 - accuracy: 0.6978 - val_loss: 0.9459 - val_accuracy: 0.6074
# Epoch 166/250
# 17/17 [==============================] - 0s 4ms/step - loss: 0.7742 - accuracy: 0.6978 - val_loss: 0.9584 - val_accuracy: 0.6222
# Epoch 167/250
# 17/17 [==============================] - 0s 4ms/step - loss: 0.7942 - accuracy: 0.7090 - val_loss: 0.9506 - val_accuracy: 0.6148
# Epoch 168/250
# 17/17 [==============================] - 0s 4ms/step - loss: 0.7485 - accuracy: 0.7052 - val_loss: 0.9597 - val_accuracy: 0.6148
# Epoch 169/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.7894 - accuracy: 0.7015 - val_loss: 0.9772 - val_accuracy: 0.6222
# Epoch 170/250
# 17/17 [==============================] - 0s 4ms/step - loss: 0.7432 - accuracy: 0.7071 - val_loss: 0.9728 - val_accuracy: 0.6222
# Epoch 171/250
# 17/17 [==============================] - 0s 4ms/step - loss: 0.7449 - accuracy: 0.7183 - val_loss: 0.9783 - val_accuracy: 0.6222
# Epoch 172/250
# 17/17 [==============================] - 0s 4ms/step - loss: 0.7780 - accuracy: 0.7015 - val_loss: 0.9866 - val_accuracy: 0.6296
# Epoch 173/250
# 17/17 [==============================] - 0s 12ms/step - loss: 0.7721 - accuracy: 0.7052 - val_loss: 0.9861 - val_accuracy: 0.6296
# Epoch 174/250
# 17/17 [==============================] - 0s 4ms/step - loss: 0.7278 - accuracy: 0.7164 - val_loss: 0.9896 - val_accuracy: 0.6222
# Epoch 175/250
# 17/17 [==============================] - 0s 4ms/step - loss: 0.7298 - accuracy: 0.7257 - val_loss: 0.9826 - val_accuracy: 0.6222
# Epoch 176/250
# 17/17 [==============================] - 0s 4ms/step - loss: 0.7554 - accuracy: 0.7183 - val_loss: 0.9679 - val_accuracy: 0.6296
# Epoch 177/250
# 17/17 [==============================] - 0s 4ms/step - loss: 0.7658 - accuracy: 0.7183 - val_loss: 0.9679 - val_accuracy: 0.6222
# Epoch 178/250
# 17/17 [==============================] - 0s 4ms/step - loss: 0.7641 - accuracy: 0.7071 - val_loss: 0.9659 - val_accuracy: 0.6296
# Epoch 179/250
# 17/17 [==============================] - 0s 4ms/step - loss: 0.7277 - accuracy: 0.7220 - val_loss: 0.9475 - val_accuracy: 0.6222
# Epoch 180/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.7646 - accuracy: 0.7052 - val_loss: 0.9440 - val_accuracy: 0.6222
# Epoch 181/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.7850 - accuracy: 0.7164 - val_loss: 0.9467 - val_accuracy: 0.6222
# Epoch 182/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.7277 - accuracy: 0.6940 - val_loss: 0.9541 - val_accuracy: 0.6222
# Epoch 183/250
# 17/17 [==============================] - 0s 4ms/step - loss: 0.7433 - accuracy: 0.7108 - val_loss: 0.9595 - val_accuracy: 0.6370
# Epoch 184/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.7418 - accuracy: 0.7090 - val_loss: 0.9633 - val_accuracy: 0.6444
# Epoch 185/250
# 17/17 [==============================] - 0s 4ms/step - loss: 0.7232 - accuracy: 0.7052 - val_loss: 0.9786 - val_accuracy: 0.6296
# Epoch 186/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.7757 - accuracy: 0.7071 - val_loss: 0.9652 - val_accuracy: 0.6296
# Epoch 187/250
# 17/17 [==============================] - 0s 4ms/step - loss: 0.7522 - accuracy: 0.7164 - val_loss: 0.9659 - val_accuracy: 0.6296
# Epoch 188/250
# 17/17 [==============================] - 0s 7ms/step - loss: 0.7465 - accuracy: 0.6996 - val_loss: 0.9707 - val_accuracy: 0.6296
# Epoch 189/250
# 17/17 [==============================] - 0s 4ms/step - loss: 0.7407 - accuracy: 0.7015 - val_loss: 0.9772 - val_accuracy: 0.6296
# Epoch 190/250
# 17/17 [==============================] - 0s 4ms/step - loss: 0.7233 - accuracy: 0.7146 - val_loss: 0.9683 - val_accuracy: 0.6296
# Epoch 191/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.7215 - accuracy: 0.7257 - val_loss: 0.9660 - val_accuracy: 0.6296
# Epoch 192/250
# 17/17 [==============================] - 0s 4ms/step - loss: 0.6833 - accuracy: 0.7369 - val_loss: 0.9823 - val_accuracy: 0.6296
# Epoch 193/250
# 17/17 [==============================] - 0s 4ms/step - loss: 0.6841 - accuracy: 0.7463 - val_loss: 0.9797 - val_accuracy: 0.6222
# Epoch 194/250
# 17/17 [==============================] - 0s 11ms/step - loss: 0.6770 - accuracy: 0.7257 - val_loss: 0.9687 - val_accuracy: 0.6296
# Epoch 195/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.7433 - accuracy: 0.7071 - val_loss: 0.9660 - val_accuracy: 0.6148
# Epoch 196/250
# 17/17 [==============================] - 0s 4ms/step - loss: 0.7295 - accuracy: 0.7090 - val_loss: 0.9711 - val_accuracy: 0.6296
# Epoch 197/250
# 17/17 [==============================] - 0s 4ms/step - loss: 0.7191 - accuracy: 0.7220 - val_loss: 0.9786 - val_accuracy: 0.6222
# Epoch 198/250
# 17/17 [==============================] - 0s 4ms/step - loss: 0.7005 - accuracy: 0.7295 - val_loss: 0.9869 - val_accuracy: 0.6222
# Epoch 199/250
# 17/17 [==============================] - 0s 4ms/step - loss: 0.6962 - accuracy: 0.7239 - val_loss: 0.9848 - val_accuracy: 0.6222
# Epoch 200/250
# 17/17 [==============================] - 0s 4ms/step - loss: 0.7001 - accuracy: 0.7407 - val_loss: 0.9760 - val_accuracy: 0.6222
# Epoch 201/250
# 17/17 [==============================] - 0s 4ms/step - loss: 0.7028 - accuracy: 0.7407 - val_loss: 0.9615 - val_accuracy: 0.6074
# Epoch 202/250
# 17/17 [==============================] - 0s 4ms/step - loss: 0.7152 - accuracy: 0.7332 - val_loss: 0.9575 - val_accuracy: 0.6148
# Epoch 203/250
# 17/17 [==============================] - 0s 4ms/step - loss: 0.6810 - accuracy: 0.7407 - val_loss: 0.9619 - val_accuracy: 0.6148
# Epoch 204/250
# 17/17 [==============================] - 0s 4ms/step - loss: 0.7054 - accuracy: 0.7425 - val_loss: 0.9737 - val_accuracy: 0.6222
# Epoch 205/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.7045 - accuracy: 0.7201 - val_loss: 0.9876 - val_accuracy: 0.6296
# Epoch 206/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.6894 - accuracy: 0.7369 - val_loss: 0.9800 - val_accuracy: 0.6222
# Epoch 207/250
# 17/17 [==============================] - 0s 6ms/step - loss: 0.7120 - accuracy: 0.7052 - val_loss: 0.9607 - val_accuracy: 0.6222
# Epoch 208/250
# 17/17 [==============================] - 0s 6ms/step - loss: 0.6858 - accuracy: 0.7425 - val_loss: 0.9672 - val_accuracy: 0.6222
# Epoch 209/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.6972 - accuracy: 0.7257 - val_loss: 0.9746 - val_accuracy: 0.6296
# Epoch 210/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.6852 - accuracy: 0.7332 - val_loss: 0.9786 - val_accuracy: 0.6222
# Epoch 211/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.6726 - accuracy: 0.7481 - val_loss: 0.9781 - val_accuracy: 0.6222
# Epoch 212/250
# 17/17 [==============================] - 0s 4ms/step - loss: 0.6892 - accuracy: 0.7183 - val_loss: 0.9756 - val_accuracy: 0.6296
# Epoch 213/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.7350 - accuracy: 0.7164 - val_loss: 0.9820 - val_accuracy: 0.6222
# Epoch 214/250
# 17/17 [==============================] - 0s 11ms/step - loss: 0.6806 - accuracy: 0.7425 - val_loss: 0.9867 - val_accuracy: 0.6222
# Epoch 215/250
# 17/17 [==============================] - 0s 6ms/step - loss: 0.6530 - accuracy: 0.7351 - val_loss: 0.9792 - val_accuracy: 0.6222
# Epoch 216/250
# 17/17 [==============================] - 0s 4ms/step - loss: 0.6620 - accuracy: 0.7556 - val_loss: 0.9713 - val_accuracy: 0.6222
# Epoch 217/250
# 17/17 [==============================] - 0s 6ms/step - loss: 0.6987 - accuracy: 0.7127 - val_loss: 0.9796 - val_accuracy: 0.6296
# Epoch 218/250
# 17/17 [==============================] - 0s 4ms/step - loss: 0.6469 - accuracy: 0.7295 - val_loss: 0.9905 - val_accuracy: 0.6370
# Epoch 219/250
# 17/17 [==============================] - 0s 4ms/step - loss: 0.6794 - accuracy: 0.7351 - val_loss: 0.9800 - val_accuracy: 0.6222
# Epoch 220/250
# 17/17 [==============================] - 0s 6ms/step - loss: 0.6723 - accuracy: 0.7276 - val_loss: 0.9956 - val_accuracy: 0.6296
# Epoch 221/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.6746 - accuracy: 0.7425 - val_loss: 1.0177 - val_accuracy: 0.6148
# Epoch 222/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.6871 - accuracy: 0.7257 - val_loss: 1.0128 - val_accuracy: 0.6074
# Epoch 223/250
# 17/17 [==============================] - 0s 4ms/step - loss: 0.7121 - accuracy: 0.7201 - val_loss: 0.9890 - val_accuracy: 0.6222
# Epoch 224/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.7020 - accuracy: 0.7295 - val_loss: 0.9766 - val_accuracy: 0.6296
# Epoch 225/250
# 17/17 [==============================] - 0s 4ms/step - loss: 0.6571 - accuracy: 0.7519 - val_loss: 0.9763 - val_accuracy: 0.6296
# Epoch 226/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.6480 - accuracy: 0.7313 - val_loss: 1.0012 - val_accuracy: 0.6222
# Epoch 227/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.6528 - accuracy: 0.7276 - val_loss: 1.0192 - val_accuracy: 0.6296
# Epoch 228/250
# 17/17 [==============================] - 0s 4ms/step - loss: 0.7111 - accuracy: 0.7313 - val_loss: 1.0132 - val_accuracy: 0.6222
# Epoch 229/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.6500 - accuracy: 0.7668 - val_loss: 1.0113 - val_accuracy: 0.6148
# Epoch 230/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.6553 - accuracy: 0.7481 - val_loss: 0.9806 - val_accuracy: 0.6296
# Epoch 231/250
# 17/17 [==============================] - 0s 4ms/step - loss: 0.6621 - accuracy: 0.7444 - val_loss: 0.9691 - val_accuracy: 0.6222
# Epoch 232/250
# 17/17 [==============================] - 0s 4ms/step - loss: 0.6619 - accuracy: 0.7369 - val_loss: 0.9874 - val_accuracy: 0.6296
# Epoch 233/250
# 17/17 [==============================] - 0s 4ms/step - loss: 0.6486 - accuracy: 0.7463 - val_loss: 1.0010 - val_accuracy: 0.6222
# Epoch 234/250
# 17/17 [==============================] - 0s 12ms/step - loss: 0.6467 - accuracy: 0.7463 - val_loss: 1.0105 - val_accuracy: 0.6296
# Epoch 235/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.6374 - accuracy: 0.7444 - val_loss: 1.0101 - val_accuracy: 0.6148
# Epoch 236/250
# 17/17 [==============================] - 0s 4ms/step - loss: 0.6627 - accuracy: 0.7276 - val_loss: 1.0171 - val_accuracy: 0.6296
# Epoch 237/250
# 17/17 [==============================] - 0s 4ms/step - loss: 0.6304 - accuracy: 0.7519 - val_loss: 1.0269 - val_accuracy: 0.6148
# Epoch 238/250
# 17/17 [==============================] - 0s 4ms/step - loss: 0.6881 - accuracy: 0.7388 - val_loss: 1.0174 - val_accuracy: 0.6148
# Epoch 239/250
# 17/17 [==============================] - 0s 4ms/step - loss: 0.6648 - accuracy: 0.7481 - val_loss: 1.0337 - val_accuracy: 0.6148
# Epoch 240/250
# 17/17 [==============================] - 0s 4ms/step - loss: 0.6094 - accuracy: 0.7500 - val_loss: 1.0369 - val_accuracy: 0.6222
# Epoch 241/250
# 17/17 [==============================] - 0s 4ms/step - loss: 0.6703 - accuracy: 0.7369 - val_loss: 1.0251 - val_accuracy: 0.6148
# Epoch 242/250
# 17/17 [==============================] - 0s 4ms/step - loss: 0.6214 - accuracy: 0.7500 - val_loss: 1.0201 - val_accuracy: 0.6074
# Epoch 243/250
# 17/17 [==============================] - 0s 7ms/step - loss: 0.6481 - accuracy: 0.7425 - val_loss: 1.0215 - val_accuracy: 0.6148
# Epoch 244/250
# 17/17 [==============================] - 0s 4ms/step - loss: 0.6301 - accuracy: 0.7500 - val_loss: 1.0268 - val_accuracy: 0.6148
# Epoch 245/250
# 17/17 [==============================] - 0s 4ms/step - loss: 0.6554 - accuracy: 0.7519 - val_loss: 1.0209 - val_accuracy: 0.6148
# Epoch 246/250
# 17/17 [==============================] - 0s 4ms/step - loss: 0.6673 - accuracy: 0.7407 - val_loss: 1.0142 - val_accuracy: 0.6074
# Epoch 247/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.6441 - accuracy: 0.7425 - val_loss: 1.0171 - val_accuracy: 0.6074
# Epoch 248/250
# 17/17 [==============================] - 0s 5ms/step - loss: 0.6528 - accuracy: 0.7575 - val_loss: 1.0259 - val_accuracy: 0.6074
# Epoch 249/250
# 17/17 [==============================] - 0s 4ms/step - loss: 0.6879 - accuracy: 0.7313 - val_loss: 1.0215 - val_accuracy: 0.6148
# Epoch 250/250
# 17/17 [==============================] - 0s 4ms/step - loss: 0.6725 - accuracy: 0.7239 - val_loss: 1.0112 - val_accuracy: 0.6222
# 5/5 [==============================] - 0s 1ms/step

# %%
from sklearn.metrics import accuracy_score

# Accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")
# Out:
# Accuracy: 0.62

# %% [markdown]
# ### **With SMOTE**

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from imblearn.over_sampling import SMOTE
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score, precision_score, recall_score, f1_score
from collections import Counter
from tensorflow.keras.layers import Input, Dense, Dropout
from keras.models import Model, Sequential
from tensorflow.keras.callbacks import EarlyStopping
from keras.optimizers import Adam

# Load the dataset
omics_data = pd.read_csv(r'D:\uni dina\4Y SEM 8\Bioinformatics Modeling and Simulation\_GROUP PROJECT\VERSION 3\DATASET\cnv_data_5000.csv')
labels = pd.read_csv(r'D:\uni dina\4Y SEM 8\Bioinformatics Modeling and Simulation\_GROUP PROJECT\VERSION 3\DATASET\BRCA_label.csv')

# %%
omics_data

# %%
# Preprocess the labels
label_encoder = LabelEncoder()
labels['label_encoded'] = label_encoder.fit_transform(labels['Label'])

# Print label mappings
label_mappings = dict(zip(label_encoder.classes_, label_encoder.transform(label_encoder.classes_)))
print("Label Mappings:")
for label, encoded_value in label_mappings.items():
    print(f"{label} - {encoded_value}")

# %%
# Print class distribution
class_distribution = Counter(labels['label_encoded'])
print("\nClass Distribution:")
for label, count in class_distribution.items():
    for key, value in label_mappings.items():
        if value == label:
            print(f"{key} - {label} - {count}")

# %%
omics_data = omics_data.iloc[:, 1:]
omics_data

# %%
# Split the data
X_train, X_test, y_train, y_test = train_test_split(omics_data, labels['label_encoded'], test_size=0.2, random_state=42)

# Print class distribution before SMOTE
print("Class distribution before SMOTE:")
print(pd.Series(y_train).value_counts())

# %%
# Split data into training and test sets
x_train, x_test, y_train, y_test = train_test_split(omics_data, labels['label_encoded'], test_size=0.2, random_state=42)

# Apply SMOTE to balance the training data
smote = SMOTE(random_state=42)
x_train_smote, y_train_smote = smote.fit_resample(x_train, y_train)

# Print class distribution after SMOTE
print("\nClass distribution after SMOTE:")
print(pd.Series(y_train_smote).value_counts())

# %%
# Standardize the data
scaler = StandardScaler()
x_train_smote = scaler.fit_transform(x_train_smote)
x_test = scaler.transform(x_test)

# Define the architecture parameters for the SDAE
input_dim = x_train_smote.shape[1]
hidden1_dim = 64
hidden2_dim = 32
encoding_dim = 16

# Build the SDAE model
input_layer = Input(shape=(input_dim,))
hidden1 = Dense(hidden1_dim, activation='relu')(input_layer)
encoded1 = Dense(hidden2_dim, activation='relu')(hidden1)
encoded2 = Dense(encoding_dim, activation='relu')(encoded1)
decoded1 = Dense(hidden2_dim, activation='relu')(encoded2)
decoded2 = Dense(hidden1_dim, activation='relu')(decoded1)
output_layer = Dense(input_dim, activation='linear')(decoded2)

sdae = Model(inputs=input_layer, outputs=output_layer)

# Compile the SDAE model
sdae.compile(optimizer='adam', loss='mean_squared_error')

# Train the SDAE
num_epochs = 250
batch_size = 32
sdae.fit(x_train_smote, x_train_smote, epochs=num_epochs, batch_size=batch_size, shuffle=True, validation_data=(x_test, x_test))

# Extract the encoder part for feature extraction
encoder = Model(inputs=input_layer, outputs=encoded2)

# Extract features using the encoder
X_train_encoded = encoder.predict(x_train_smote)
X_test_encoded = encoder.predict(x_test)

# Define a classifier (example: simple MLP classifier)
num_classes = len(np.unique(y_train))
classifier = Sequential([
    Dense(64, activation='relu', input_dim=encoding_dim),
    Dropout(0.5),
    Dense(32, activation='relu'),
    Dropout(0.5),
    Dense(num_classes, activation='softmax')
])

# Compile and train the classifier
classifier.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
num_epochs = 250
batch_size = 32
classifier.fit(X_train_encoded, y_train_smote, epochs=num_epochs, batch_size=batch_size, validation_data=(X_test_encoded, y_test))

# Predict probabilities
y_pred_prob = classifier.predict(X_test_encoded)

# Convert probabilities to class labels
y_pred = np.argmax(y_pred_prob, axis=1)

# Evaluate the classifier
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy}')
print(classification_report(y_test, y_pred))

# %%
# Evaluate model
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')

print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")

# Detailed classification report
print(classification_report(y_test, y_pred, target_names=label_encoder.classes_))

# %% [markdown]
# ## **3rd Variation: mRNA**

# %%
# Load the dataset
file_path = 'mRNA_data_5000.csv'  # Make sure the file is in the same directory or provide the correct path
mRNA = pd.read_csv(file_path)
label = pd.read_csv("BRCA_label.csv")

# %%
# Print the number of rows and columns
print(f"Number of rows (labels): {label.shape[0]}")
print(f"Number of columns (labels): {label.shape[1]}")

# Print the number of features
print(f"Number of features (labels): {label.shape[1]}")
print('\n')

# Print the number of rows and columns
print(f"Number of rows (mRNA): {mRNA.shape[0]}")
print(f"Number of columns (mRNA): {mRNA.shape[1]}")

# Print the number of features
print(f"Number of features (mRNA): {mRNA.shape[1]}")

# %%
label.head(10)

# %%
# Replace label with numerical data
label['Label'].replace('Normal', 0, inplace=True)
label['Label'].replace('LumA', 1, inplace=True)
label['Label'].replace('LumB', 2, inplace=True)
label['Label'].replace('Basal', 3, inplace=True)
label['Label'].replace('Her2', 4, inplace=True)

# Print the updated dataset
print(label)

# %%
# Check for missing values 
print("Missing values in label dataset:")
print(label.isnull().sum())
print("\n")

print("Missing values in miRNA dataset:")
print(mRNA.isnull().sum())

# %%
# Add Label
mRNA['Label'] = label['Label'].values
mRNA.head(5)

# %% [markdown]
# ### **Without SMOTE**

# %%
train_data, test_data = train_test_split(mRNA,test_size=0.20,random_state=1)
target="Label"
X_train = train_data.select_dtypes(include=["number"]).copy()
y_train = train_data[target]
X_test = test_data.select_dtypes(include=["number"]).copy()
y_test = test_data[target]

# %%
# Standardize the data
scaler = StandardScaler()
x_train_mRNA = scaler.fit_transform(X_train)
x_test_mRNA = scaler.transform(X_test)

# Define the architecture parameters
input_dim = x_train_mRNA.shape[1]
hidden1_dim = 64
hidden2_dim = 32
encoding_dim = 16

# Build the SDAE model
input_layer = Input(shape=(input_dim,))
hidden1 = Dense(hidden1_dim, activation='relu')(input_layer)
encoded1 = Dense(hidden2_dim, activation='relu')(hidden1)
encoded2 = Dense(encoding_dim, activation='relu')(encoded1)
decoded1 = Dense(hidden2_dim, activation='relu')(encoded2)
decoded2 = Dense(hidden1_dim, activation='relu')(decoded1)
output_layer = Dense(input_dim, activation='linear')(decoded2)

sdae = Model(inputs=input_layer, outputs=output_layer)

# Compile the SDAE model
sdae.compile(optimizer='adam', loss='mean_squared_error')

# Train the SDAE
num_epochs = 250
batch_size = 32
sdae.fit(x_train_mRNA, x_train_mRNA, epochs=num_epochs, batch_size=batch_size, shuffle=True, validation_data=(x_test_miRNA, x_test_miRNA))

# Extract the encoder part for feature extraction
encoder = Model(inputs=input_layer, outputs=encoded2)

# Extract features using the encoder
X_train_encoded = encoder.predict(x_train_mRNA)
X_test_encoded = encoder.predict(x_test_mRNA)

# Define a classifier (example: simple MLP classifier)
num_classes = len(np.unique(y_train))
classifier = Sequential([
    Dense(64, activation='relu', input_dim=encoding_dim),
    Dropout(0.5),
    Dense(32, activation='relu'),
    Dropout(0.5),
    Dense(num_classes, activation='softmax')
])

# Compile and train the classifier
classifier.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
num_epochs = 250
batch_size = 32
classifier.fit(X_train_encoded, y_train, epochs=num_epochs, batch_size=batch_size, validation_data=(X_test_encoded, y_test))

# Predict probabilities
y_pred_prob = classifier.predict(X_test_encoded)

# Convert probabilities to class labels
y_pred = np.argmax(y_pred_prob, axis=1)

# %%
from sklearn.metrics import accuracy_score

# Accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")

# %% [markdown]
# ### **With SMOTE**

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from imblearn.over_sampling import SMOTE
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score, precision_score, recall_score, f1_score
from collections import Counter
from tensorflow.keras.layers import Input, Dense, Dropout
from keras.models import Model, Sequential
from tensorflow.keras.callbacks import EarlyStopping
from keras.optimizers import Adam

# Load the dataset
omics_data = pd.read_csv(r'D:\uni dina\4Y SEM 8\Bioinformatics Modeling and Simulation\_GROUP PROJECT\VERSION 3\DATASET\mRNA_data_5000.csv')
labels = pd.read_csv(r'D:\uni dina\4Y SEM 8\Bioinformatics Modeling and Simulation\_GROUP PROJECT\VERSION 3\DATASET\BRCA_label.csv')

# %%
omics_data

# %%
# Preprocess the labels
label_encoder = LabelEncoder()
labels['label_encoded'] = label_encoder.fit_transform(labels['Label'])

# Print label mappings
label_mappings = dict(zip(label_encoder.classes_, label_encoder.transform(label_encoder.classes_)))
print("Label Mappings:")
for label, encoded_value in label_mappings.items():
    print(f"{label} - {encoded_value}")

# %%
# Print class distribution
class_distribution = Counter(labels['label_encoded'])
print("\nClass Distribution:")
for label, count in class_distribution.items():
    for key, value in label_mappings.items():
        if value == label:
            print(f"{key} - {label} - {count}")

# %%
omics_data = omics_data.iloc[:, 1:]
omics_data

# %%
# Split the data
X_train, X_test, y_train, y_test = train_test_split(omics_data, labels['label_encoded'], test_size=0.2, random_state=42)

# Print class distribution before SMOTE
print("Class distribution before SMOTE:")
print(pd.Series(y_train).value_counts())

# %%
# Split data into training and test sets
x_train, x_test, y_train, y_test = train_test_split(omics_data, labels['label_encoded'], test_size=0.2, random_state=42)

# Apply SMOTE to balance the training data
smote = SMOTE(random_state=42)
x_train_smote, y_train_smote = smote.fit_resample(x_train, y_train)

# Print class distribution after SMOTE
print("\nClass distribution after SMOTE:")
print(pd.Series(y_train_smote).value_counts())

# %%
# Standardize the data
scaler = StandardScaler()
x_train_smote = scaler.fit_transform(x_train_smote)
x_test = scaler.transform(x_test)

# Define the architecture parameters for the SDAE
input_dim = x_train_smote.shape[1]
hidden1_dim = 64
hidden2_dim = 32
encoding_dim = 16

# Build the SDAE model
input_layer = Input(shape=(input_dim,))
hidden1 = Dense(hidden1_dim, activation='relu')(input_layer)
encoded1 = Dense(hidden2_dim, activation='relu')(hidden1)
encoded2 = Dense(encoding_dim, activation='relu')(encoded1)
decoded1 = Dense(hidden2_dim, activation='relu')(encoded2)
decoded2 = Dense(hidden1_dim, activation='relu')(decoded1)
output_layer = Dense(input_dim, activation='linear')(decoded2)

sdae = Model(inputs=input_layer, outputs=output_layer)

# Compile the SDAE model
sdae.compile(optimizer='adam', loss='mean_squared_error')

# Train the SDAE
num_epochs = 250
batch_size = 32
sdae.fit(x_train_smote, x_train_smote, epochs=num_epochs, batch_size=batch_size, shuffle=True, validation_data=(x_test, x_test))

# Extract the encoder part for feature extraction
encoder = Model(inputs=input_layer, outputs=encoded2)

# Extract features using the encoder
X_train_encoded = encoder.predict(x_train_smote)
X_test_encoded = encoder.predict(x_test)

# Define a classifier (example: simple MLP classifier)
num_classes = len(np.unique(y_train))
classifier = Sequential([
    Dense(64, activation='relu', input_dim=encoding_dim),
    Dropout(0.5),
    Dense(32, activation='relu'),
    Dropout(0.5),
    Dense(num_classes, activation='softmax')
])

# Compile and train the classifier
classifier.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
num_epochs = 250
batch_size = 32
classifier.fit(X_train_encoded, y_train_smote, epochs=num_epochs, batch_size=batch_size, validation_data=(X_test_encoded, y_test))

# Predict probabilities
y_pred_prob = classifier.predict(X_test_encoded)

# Convert probabilities to class labels
y_pred = np.argmax(y_pred_prob, axis=1)

# Evaluate the classifier
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy}')
print(classification_report(y_test, y_pred))

# %%
# Evaluate model
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')

print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")

# Detailed classification report
print(classification_report(y_test, y_pred, target_names=label_encoder.classes_))

# %% [markdown]
# # **Single Omics Variation: miRNA + Copy Number Variation (CNV) + DNA_Methylation + mRNA**

# %%
# Load the dataset
file_path = 'concat_data_30000_latest.csv'  # Make sure the file is in the same directory or provide the correct path
combined = pd.read_csv(file_path)
label = pd.read_csv("BRCA_label.csv")

# %%
# Print the number of rows and columns
print(f"Number of rows (labels): {label.shape[0]}")
print(f"Number of columns (labels): {label.shape[1]}")

# Print the number of features
print(f"Number of features (labels): {label.shape[1]}")
print('\n')

# Print the number of rows and columns
print(f"Number of rows (combined): {combined.shape[0]}")
print(f"Number of columns (combined): {combined.shape[1]}")

# Print the number of features
print(f"Number of features (combined): {combined.shape[1]}")

# %%
label.head(10)

# %%
# Replace label with numerical data
label['Label'].replace('Normal', 0, inplace=True)
label['Label'].replace('LumA', 1, inplace=True)
label['Label'].replace('LumB', 2, inplace=True)
label['Label'].replace('Basal', 3, inplace=True)
label['Label'].replace('Her2', 4, inplace=True)

# Print the updated dataset
print(label)

# %%
# CHECK FOR MISSING VALUES  
print("Missing values in label dataset:")
print(label.isnull().sum())
print("\n")

print("Missing values in miRNA dataset:")
print(combined.isnull().sum())

# %%
# ADD LABEL
combined['Label'] = label['Label'].values
combined.head(5)

# %% [markdown]
# ### **Without SMOTE**

# %%
train_data, test_data = train_test_split(combined,test_size=0.20,random_state=1)
target="Label"
X_train = train_data.select_dtypes(include=["number"]).copy()
y_train = train_data[target]
X_test = test_data.select_dtypes(include=["number"]).copy()
y_test = test_data[target]

# %%
# Standardize the data
scaler = StandardScaler()# For consistency
x_train_combined = scaler.fit_transform(X_train)
x_test_combined = scaler.transform(X_test)

# Define the architecture parameters
input_dim = x_train_combined.shape[1] #Read features second column
hidden1_dim = 64 #First hidden layer
hidden2_dim = 32 #Second hidden layer
encoding_dim = 16 

# Build the SDAE model
input_layer = Input(shape=(input_dim,))
hidden1 = Dense(hidden1_dim, activation='relu')(input_layer)
encoded1 = Dense(hidden2_dim, activation='relu')(hidden1)
encoded2 = Dense(encoding_dim, activation='relu')(encoded1)
decoded1 = Dense(hidden2_dim, activation='relu')(encoded2)
decoded2 = Dense(hidden1_dim, activation='relu')(decoded1)
output_layer = Dense(input_dim, activation='linear')(decoded2)

sdae = Model(inputs=input_layer, outputs=output_layer)

# Compile the SDAE model
sdae.compile(optimizer='adam', loss='mean_squared_error') #Use adam as bias correction
                                                          
# Train the SDAE
num_epochs = 250
batch_size = 32
sdae.fit(x_train_combined, x_train_combined, epochs=num_epochs, batch_size=batch_size, shuffle=True, validation_data=(x_test_miRNA, x_test_miRNA))

# Extract the encoder part for feature extraction
encoder = Model(inputs=input_layer, outputs=encoded2)

# Extract features using the encoder
X_train_encoded = encoder.predict(x_train_miRNA)
X_test_encoded = encoder.predict(x_test_miRNA)

# Define a classifier (example: simple MLP classifier)
num_classes = len(np.unique(y_train))
classifier = Sequential([
    Dense(64, activation='relu', input_dim=encoding_dim),
    Dropout(0.5),
    Dense(32, activation='relu'),
    Dropout(0.5),
    Dense(num_classes, activation='softmax')
])

# Compile and train the classifier
classifier.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
num_epochs = 250
batch_size = 32
classifier.fit(X_train_encoded, y_train, epochs=num_epochs, batch_size=batch_size, validation_data=(X_test_encoded, y_test))

# Predict probabilities
y_pred_prob = classifier.predict(X_test_encoded)

# Convert probabilities to class labels
y_pred = np.argmax(y_pred_prob, axis=1)

# %%
from sklearn.metrics import accuracy_score

# Accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")

# %% [markdown]
# ### **With SMOTE**

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from imblearn.over_sampling import SMOTE
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score, precision_score, recall_score, f1_score
from collections import Counter
from tensorflow.keras.layers import Input, Dense, Dropout
from keras.models import Model, Sequential
from tensorflow.keras.callbacks import EarlyStopping
from keras.optimizers import Adam

# Load the dataset
omics_data = pd.read_csv(r'D:\uni dina\4Y SEM 8\Bioinformatics Modeling and Simulation\_GROUP PROJECT\VERSION 3\DATASET\concat_data_30000_latest.csv')
labels = pd.read_csv(r'D:\uni dina\4Y SEM 8\Bioinformatics Modeling and Simulation\_GROUP PROJECT\VERSION 3\DATASET\BRCA_label.csv')

# %%
omics_data

# %%
# Preprocess the labels
label_encoder = LabelEncoder()
labels['label_encoded'] = label_encoder.fit_transform(labels['Label'])

# Print label mappings
label_mappings = dict(zip(label_encoder.classes_, label_encoder.transform(label_encoder.classes_)))
print("Label Mappings:")
for label, encoded_value in label_mappings.items():
    print(f"{label} - {encoded_value}")

# %%
# Print class distribution
class_distribution = Counter(labels['label_encoded'])
print("\nClass Distribution:")
for label, count in class_distribution.items():
    for key, value in label_mappings.items():
        if value == label:
            print(f"{key} - {label} - {count}")

# %%
omics_data = omics_data.iloc[:, 1:]
omics_data

# %%
# Split the data
X_train, X_test, y_train, y_test = train_test_split(omics_data, labels['label_encoded'], test_size=0.2, random_state=42)

# Print class distribution before SMOTE
print("Class distribution before SMOTE:")
print(pd.Series(y_train).value_counts())

# %%
# Split data into training and test sets
x_train, x_test, y_train, y_test = train_test_split(omics_data, labels['label_encoded'], test_size=0.2, random_state=42)

# Apply SMOTE to balance the training data
smote = SMOTE(random_state=42)
x_train_smote, y_train_smote = smote.fit_resample(x_train, y_train)

# Print class distribution after SMOTE
print("\nClass distribution after SMOTE:")
print(pd.Series(y_train_smote).value_counts())

# %%
# Standardize the data
scaler = StandardScaler()
x_train_smote = scaler.fit_transform(x_train_smote)
x_test = scaler.transform(x_test)

# Define the architecture parameters for the SDAE
input_dim = x_train_smote.shape[1]
hidden1_dim = 64
hidden2_dim = 32
encoding_dim = 16

# Build the SDAE model
input_layer = Input(shape=(input_dim,))
hidden1 = Dense(hidden1_dim, activation='relu')(input_layer)
encoded1 = Dense(hidden2_dim, activation='relu')(hidden1)
encoded2 = Dense(encoding_dim, activation='relu')(encoded1)
decoded1 = Dense(hidden2_dim, activation='relu')(encoded2)
decoded2 = Dense(hidden1_dim, activation='relu')(decoded1)
output_layer = Dense(input_dim, activation='linear')(decoded2)

sdae = Model(inputs=input_layer, outputs=output_layer)

# Compile the SDAE model
sdae.compile(optimizer='adam', loss='mean_squared_error')

# Train the SDAE
num_epochs = 250
batch_size = 32
sdae.fit(x_train_smote, x_train_smote, epochs=num_epochs, batch_size=batch_size, shuffle=True, validation_data=(x_test, x_test))

# Extract the encoder part for feature extraction
encoder = Model(inputs=input_layer, outputs=encoded2)

# Extract features using the encoder
X_train_encoded = encoder.predict(x_train_smote)
X_test_encoded = encoder.predict(x_test)

# Define a classifier (example: simple MLP classifier)
num_classes = len(np.unique(y_train))
classifier = Sequential([
    Dense(64, activation='relu', input_dim=encoding_dim),
    Dropout(0.5),
    Dense(32, activation='relu'),
    Dropout(0.5),
    Dense(num_classes, activation='softmax')
])

# Compile and train the classifier
classifier.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
num_epochs = 250
batch_size = 32
classifier.fit(X_train_encoded, y_train_smote, epochs=num_epochs, batch_size=batch_size, validation_data=(X_test_encoded, y_test))

# Predict probabilities
y_pred_prob = classifier.predict(X_test_encoded)

# Convert probabilities to class labels
y_pred = np.argmax(y_pred_prob, axis=1)

# Evaluate the classifier
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy}')
print(classification_report(y_test, y_pred))

# %%
# Evaluate model
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')

print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")

# Detailed classification report
print(classification_report(y_test, y_pred, target_names=label_encoder.classes_))
